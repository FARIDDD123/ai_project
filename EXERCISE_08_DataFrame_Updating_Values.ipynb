# %% [markdown]
# ## SOLUTION Updating Data Exercise
#
# **This exercise uses the `netflix_titles.csv` dataset**

# %% [markdown]
# ### read in the netflix_titles.csv dataset.  Make sure to tell pandas to use the correct separator character!

# %%
import pandas as pd
netflix = pd.read_csv('DataAnalysis/data/netflix_titles.csv', sep='|', index_col=0)
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %% [markdown]
# ### set the index to be the "show_id" (inplace)

# %%
netflix.set_index("show_id", inplace=True)

# %% [markdown]
# ### Find the row with the id of s2202 and set its director to "Greg Whiteley"

# %%
netflix.loc['s2202', 'director'] = 'Greg Whiteley'

# %%
netflix.loc[['s2202', 's8806']]
# Out:
#             type          title       director  \
# show_id
# s2202    TV Show  Last Chance U  Greg Whiteley
# s8806      Movie           Zoom   Peter Hewitt
#
#                                                       cast        country  \
# show_id
# s2202    John Franklin III, DJ Law, Buddy Stephens, Bri...  United States
# s8806    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
#
#                date_added  release_year rating   duration  \
# show_id
# s2202       July 28, 2020          2020  TV-MA  5 Seasons
# s8806    January 11, 2020          2006     PG     88 min
#
#                                   listed_in  \
# show_id
# s2202                            Docuseries
# s8806    Children & Family Movies, Comedies
#
#                                                description
# show_id
# s2202    In a docuseries set at one of NCAA football's ...
# s8806    Dragged from civilian life, a former superhero...

# %% [markdown]
# ### Update the "duration" of the shows with index s2881 and s3601 to be "GONE TOO SOON"

# %%
netflix.loc[['s2881','s3601'], 'duration'] = 'GONE TOO SOON'

# %%
netflix.loc[['s2881','s3601']]
# Out:
#             type                    title director  \
# show_id
# s2881    TV Show  I Am Not Okay With This      NaN
# s3601    TV Show                     GLOW      NaN
#
#                                                       cast        country  \
# show_id
# s2881    Sophia Lillis, Wyatt Oleff, Kathleen Rose Perk...  United States
# s3601    Alison Brie, Betty Gilpin, Marc Maron, Britney...  United States
#
#                 date_added  release_year rating       duration  \
# show_id
# s2881    February 26, 2020          2020  TV-MA  GONE TOO SOON
# s3601       August 9, 2019          2019  TV-MA  GONE TOO SOON
#
#                                            listed_in  \
# show_id
# s2881    TV Comedies, TV Dramas, TV Sci-Fi & Fantasy
# s3601                         TV Comedies, TV Dramas
#
#                                                description
# show_id
# s2881    Angsty Syd navigates high school awkwardness, ...
# s3601    In 1980s LA, a crew of misfits reinvent themse...

# %%
netflix
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                    ...            ...
# s8803    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# s8804                                                  NaN            NaN
# s8805    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# s8806    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# s8807    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA   1 Season
# s4       September 24, 2021          2021  TV-MA   1 Season
# s5       September 24, 2021          2021  TV-MA  2 Seasons
# ...                     ...           ...    ...        ...
# s8803     November 20, 2019          2007      R    158 min
# s8804          July 1, 2019          2018  TV-Y7  2 Seasons
# s8805      November 1, 2019          2009      R     88 min
# s8806      January 11, 2020          2006     PG     88 min
# s8807         March 2, 2019          2015  TV-14    111 min
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
# ...                                                    ...
# s8803                       Cult Movies, Dramas, Thrillers
# s8804               Kids' TV, Korean TV Shows, TV Comedies
# s8805                              Comedies, Horror Movies
# s8806                   Children & Family Movies, Comedies
# s8807       Dramas, International Movies, Music & Musicals
#
#                                                description
# show_id
# s1       As her father nears the end of his life, filmm...
# s2       After crossing paths at a party, a Cape Town t...
# s3       To protect his family from a powerful drug lor...
# s4       Feuds, flirtations and toilet talk go down amo...
# s5       In a city of coaching centers known to train I...
# ...                                                    ...
# s8803    A political cartoonist, a crime reporter and a...
# s8804    While living alone in a spooky town, a young g...
# s8805    Looking to survive in a world taken over by zo...
# s8806    Dragged from civilian life, a former superhero...
# s8807    A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 11 columns]

# %% [markdown]
# ### rename the release_year column to "release_yr" in place

# %%
netflix.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA   1 Season
# s4       September 24, 2021          2021  TV-MA   1 Season
# s5       September 24, 2021          2021  TV-MA  2 Seasons
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
#
#                                                description
# show_id
# s1       As her father nears the end of his life, filmm...
# s2       After crossing paths at a party, a Cape Town t...
# s3       To protect his family from a powerful drug lor...
# s4       Feuds, flirtations and toilet talk go down amo...
# s5       In a city of coaching centers known to train I...

# %%
netflix.rename(columns={'release_year' : 'release year'}, inplace=True)

# %%
netflix.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA   1 Season
# s4       September 24, 2021          2021  TV-MA   1 Season
# s5       September 24, 2021          2021  TV-MA  2 Seasons
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
#
#                                                description
# show_id
# s1       As her father nears the end of his life, filmm...
# s2       After crossing paths at a party, a Cape Town t...
# s3       To protect his family from a powerful drug lor...
# s4       Feuds, flirtations and toilet talk go down amo...
# s5       In a city of coaching centers known to train I...

# %%
netflix.rename({"release_year": "release_yr"}, axis=1).head()
netflix
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                    ...            ...
# s8803    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# s8804                                                  NaN            NaN
# s8805    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# s8806    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# s8807    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#                  date_added  release year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA   1 Season
# s4       September 24, 2021          2021  TV-MA   1 Season
# s5       September 24, 2021          2021  TV-MA  2 Seasons
# ...                     ...           ...    ...        ...
# s8803     November 20, 2019          2007      R    158 min
# s8804          July 1, 2019          2018  TV-Y7  2 Seasons
# s8805      November 1, 2019          2009      R     88 min
# s8806      January 11, 2020          2006     PG     88 min
# s8807         March 2, 2019          2015  TV-14    111 min
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
# ...                                                    ...
# s8803                       Cult Movies, Dramas, Thrillers
# s8804               Kids' TV, Korean TV Shows, TV Comedies
# s8805                              Comedies, Horror Movies
# s8806                   Children & Family Movies, Comedies
# s8807       Dramas, International Movies, Music & Musicals
#
#                                                description
# show_id
# s1       As her father nears the end of his life, filmm...
# s2       After crossing paths at a party, a Cape Town t...
# s3       To protect his family from a powerful drug lor...
# s4       Feuds, flirtations and toilet talk go down amo...
# s5       In a city of coaching centers known to train I...
# ...                                                    ...
# s8803    A political cartoonist, a crime reporter and a...
# s8804    While living alone in a spooky town, a young g...
# s8805    Looking to survive in a world taken over by zo...
# s8806    Dragged from civilian life, a former superhero...
# s8807    A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 11 columns]

# %% [markdown]
# ### Find the show called "Evil"
# ### Change its index label to s6666 inplace

# %%
netflix[netflix.title == 'Evil']
# Out:
#             type title director  \
# show_id
# s1907    TV Show  Evil      NaN
#
#                                                       cast        country  \
# show_id
# s1907    Katja Herbers, Mike Colter, Aasif Mandvi, Mich...  United States
#
#               date_added  release year rating  duration  listed_in  \
# show_id
# s1907    October 1, 2020          2019  TV-14  1 Season  TV Dramas
#
#                                                description
# show_id
# s1907    A forensic psychologist partners with a Cathol...

# %%
netflix.replace({"s1907": "s6666"}, inplace=True)

# %%
netflix.loc[['s6666', 's8803']]
# Out:
#           type                    title       director  \
# show_id
# s6666    Movie  Eddie Murphy: Delirious   Bruce Gowers
# s8803    Movie                   Zodiac  David Fincher
#
#                                                       cast        country  \
# show_id
# s6666                                         Eddie Murphy  United States
# s8803    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
#
#                 date_added  release year rating duration  \
# show_id
# s6666       April 15, 2018          1983  TV-MA   69 min
# s8803    November 20, 2019          2007      R  158 min
#
#                               listed_in  \
# show_id
# s6666                   Stand-Up Comedy
# s8803    Cult Movies, Dramas, Thrillers
#
#                                                description
# show_id
# s6666    Flashing the wild stand-up comedy that made hi...
# s8803    A political cartoonist, a crime reporter and a...

# %% [markdown]
# ### In the rating column, please replace all instances of "UR" and "NR" with "No Rating".  Don't do it inplace!

# %%
netflix.rating.replace(["UR", "NR"], "No Rating").value_counts()
# Out:
# TV-MA        3207
# TV-14        2160
# TV-PG         863
# R             799
# PG-13         490
# TV-Y7         334
# TV-Y          307
# PG            287
# TV-G          220
# No Rating      83
# G              41
# TV-Y7-FV        6
# NC-17           3
# 74 min          1
# 84 min          1
# 66 min          1
# Name: rating, dtype: int64

# %%
netflix["rating"].value_counts()
# Out:
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: rating, dtype: int64

# %%
 netflix["rating"].value_counts(dropna=False)
# Out:
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NaN            4
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: rating, dtype: int64

# %% [markdown]
# ### Add a new column "is_fav" and set it to False for all rows
# ### Update the "is_fav" column to True for the titles in my list of favs (provided below)

# %%
netflix["is_fav"] =False
netflix
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                    ...            ...
# s8803    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# s8804                                                  NaN            NaN
# s8805    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# s8806    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# s8807    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#                  date_added  release year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA   1 Season
# s4       September 24, 2021          2021  TV-MA   1 Season
# s5       September 24, 2021          2021  TV-MA  2 Seasons
# ...                     ...           ...    ...        ...
# s8803     November 20, 2019          2007      R    158 min
# s8804          July 1, 2019          2018  TV-Y7  2 Seasons
# s8805      November 1, 2019          2009      R     88 min
# s8806      January 11, 2020          2006     PG     88 min
# s8807         March 2, 2019          2015  TV-14    111 min
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
# ...                                                    ...
# s8803                       Cult Movies, Dramas, Thrillers
# s8804               Kids' TV, Korean TV Shows, TV Comedies
# s8805                              Comedies, Horror Movies
# s8806                   Children & Family Movies, Comedies
# s8807       Dramas, International Movies, Music & Musicals
#
#                                                description  is_fav
# show_id
# s1       As her father nears the end of his life, filmm...   False
# s2       After crossing paths at a party, a Cape Town t...   False
# s3       To protect his family from a powerful drug lor...   False
# s4       Feuds, flirtations and toilet talk go down amo...   False
# s5       In a city of coaching centers known to train I...   False
# ...                                                    ...     ...
# s8803    A political cartoonist, a crime reporter and a...   False
# s8804    While living alone in a spooky town, a young g...   False
# s8805    Looking to survive in a world taken over by zo...   False
# s8806    Dragged from civilian life, a former superhero...   False
# s8807    A scrappy but poor boy worms his way into a ty...   False
#
# [8807 rows x 12 columns]

# %%
favs = ["Young Royals", "Dark", "Big Mouth", "BoJack Horseman", "The Queen's Gambit", "American Vandal", "Russian Doll", "Godless"]

# %%
netflix.loc[netflix["title"].isin(favs), 'is_fav'] = True

# %%
netflix[netflix["title"].isin(favs)]
# Out:
#             type               title director  \
# show_id
# s618     TV Show        Young Royals      NaN
# s1591    TV Show           Big Mouth      NaN
# s1805    TV Show  The Queen's Gambit      NaN
# s2328    TV Show                Dark      NaN
# s3370    TV Show     BoJack Horseman      NaN
# s4143    TV Show        Russian Doll      NaN
# s4637    TV Show     American Vandal      NaN
# s5160    TV Show             Godless      NaN
#
#                                                       cast  \
# show_id
# s618     Edvin Ryding, Omar Rudberg, Malte Gårdinger, F...
# s1591    Nick Kroll, John Mulaney, Jessi Klein, Jason M...
# s1805    Anya Taylor-Joy, Bill Camp, Marielle Heller, T...
# s2328    Louis Hofmann, Oliver Masucci, Jördis Triebel,...
# s3370    Will Arnett, Aaron Paul, Amy Sedaris, Alison B...
# s4143    Natasha Lyonne, Charlie Barnett, Yul Vazquez, ...
# s4637    Tyler Alvarez, Griffin Gluck, Jimmy Tatro, Cam...
# s5160    Jeff Daniels, Michelle Dockery, Jack O'Connell...
#
#                         country          date_added  release year rating  \
# show_id
# s618                     Sweden        July 1, 2021          2021  TV-MA
# s1591             United States    December 4, 2020          2020  TV-MA
# s1805             United States    October 23, 2020          2020  TV-MA
# s2328    Germany, United States       June 27, 2020          2020  TV-MA
# s3370             United States    October 25, 2019          2020  TV-MA
# s4143             United States    February 1, 2019          2019  TV-MA
# s4637             United States  September 14, 2018          2018  TV-MA
# s5160             United States   November 22, 2017          2017  TV-MA
#
#           duration                                          listed_in  \
# show_id
# s618      1 Season  International TV Shows, Romantic TV Shows, TV ...
# s1591    4 Seasons                                        TV Comedies
# s1805     1 Season                                          TV Dramas
# s2328    3 Seasons  Crime TV Shows, International TV Shows, TV Dramas
# s3370    6 Seasons                                        TV Comedies
# s4143     1 Season                             TV Comedies, TV Dramas
# s4637    2 Seasons         Crime TV Shows, TV Comedies, Teen TV Shows
# s5160     1 Season                                          TV Dramas
#
#                                                description  is_fav
# show_id
# s618     Prince Wilhelm adjusts to life at his prestigi...    True
# s1591    Teenage friends find their lives upended by th...    True
# s1805    In a 1950s orphanage, a young girl reveals an ...    True
# s2328    A missing child sets four families on a franti...    True
# s3370    Meet the most beloved sitcom horse of the '90s...    True
# s4143    Nadia keeps dying and reliving her 36th birthd...    True
# s4637    A high school is rocked by an act of vandalism...    True
# s5160    A ruthless outlaw terrorizes the West in searc...    True

# %%
netflix.is_fav.value_counts()
# Out:
# False    8799
# True        8
# Name: is_fav, dtype: int64
