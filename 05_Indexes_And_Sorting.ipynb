# %%
import pandas as pd
btc = pd.read_csv('DataAnalysis/data/coin_Bitcoin.csv')

# %%
btc
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %%
btc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2991 entries, 0 to 2990
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SNo        2991 non-null   int64
#  1   Name       2991 non-null   object
#  2   Symbol     2991 non-null   object
#  3   Date       2991 non-null   object
#  4   High       2991 non-null   float64
#  5   Low        2991 non-null   float64
#  6   Open       2991 non-null   float64
#  7   Close      2991 non-null   float64
#  8   Volume     2991 non-null   float64
#  9   Marketcap  2991 non-null   float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 233.8+ KB

# %%
btc.index
# Out:
# RangeIndex(start=0, stop=2991, step=1)

# %%
btc.High
# Out:
# 0         147.488007
# 1         146.929993
# 2         139.889999
# 3         125.599998
# 4         108.127998
#             ...
# 2986    33939.588699
# 2987    34909.259899
# 2988    35937.567147
# 2989    35284.344430
# 2990    35038.536363
# Name: High, Length: 2991, dtype: float64

# %%
btc.set_index('Date')
# Out:
#                       SNo     Name Symbol          High           Low  \
# Date
# 2013-04-29 23:59:59     1  Bitcoin    BTC    147.488007    134.000000
# 2013-04-30 23:59:59     2  Bitcoin    BTC    146.929993    134.050003
# 2013-05-01 23:59:59     3  Bitcoin    BTC    139.889999    107.720001
# 2013-05-02 23:59:59     4  Bitcoin    BTC    125.599998     92.281898
# 2013-05-03 23:59:59     5  Bitcoin    BTC    108.127998     79.099998
# ...                   ...      ...    ...           ...           ...
# 2021-07-02 23:59:59  2987  Bitcoin    BTC  33939.588699  32770.680780
# 2021-07-03 23:59:59  2988  Bitcoin    BTC  34909.259899  33402.696536
# 2021-07-04 23:59:59  2989  Bitcoin    BTC  35937.567147  34396.477458
# 2021-07-05 23:59:59  2990  Bitcoin    BTC  35284.344430  33213.661034
# 2021-07-06 23:59:59  2991  Bitcoin    BTC  35038.536363  33599.916169
#
#                              Open         Close        Volume     Marketcap
# Date
# ...

# %% [markdown]
# # Note
# * for changing the original dataset you can use inplace and set it to True
# ##### or you can use index_col to change the columns thats you want to change it

# %%
btc.set_index('Date', inplace= True)

# %%
btc
# Out:
#                       SNo     Name Symbol          High           Low  \
# Date
# 2013-04-29 23:59:59     1  Bitcoin    BTC    147.488007    134.000000
# 2013-04-30 23:59:59     2  Bitcoin    BTC    146.929993    134.050003
# 2013-05-01 23:59:59     3  Bitcoin    BTC    139.889999    107.720001
# 2013-05-02 23:59:59     4  Bitcoin    BTC    125.599998     92.281898
# 2013-05-03 23:59:59     5  Bitcoin    BTC    108.127998     79.099998
# ...                   ...      ...    ...           ...           ...
# 2021-07-02 23:59:59  2987  Bitcoin    BTC  33939.588699  32770.680780
# 2021-07-03 23:59:59  2988  Bitcoin    BTC  34909.259899  33402.696536
# 2021-07-04 23:59:59  2989  Bitcoin    BTC  35937.567147  34396.477458
# 2021-07-05 23:59:59  2990  Bitcoin    BTC  35284.344430  33213.661034
# 2021-07-06 23:59:59  2991  Bitcoin    BTC  35038.536363  33599.916169
#
#                              Open         Close        Volume     Marketcap
# Date
# ...

# %%
btc.index
# Out:
# Index(['2013-04-29 23:59:59', '2013-04-30 23:59:59', '2013-05-01 23:59:59',
#        '2013-05-02 23:59:59', '2013-05-03 23:59:59', '2013-05-04 23:59:59',
#        '2013-05-05 23:59:59', '2013-05-06 23:59:59', '2013-05-07 23:59:59',
#        '2013-05-08 23:59:59',
#        ...
#        '2021-06-27 23:59:59', '2021-06-28 23:59:59', '2021-06-29 23:59:59',
#        '2021-06-30 23:59:59', '2021-07-01 23:59:59', '2021-07-02 23:59:59',
#        '2021-07-03 23:59:59', '2021-07-04 23:59:59', '2021-07-05 23:59:59',
#        '2021-07-06 23:59:59'],
#       dtype='object', name='Date', length=2991)

# %%
btc.High
# Out:
# Date
# 2013-04-29 23:59:59      147.488007
# 2013-04-30 23:59:59      146.929993
# 2013-05-01 23:59:59      139.889999
# 2013-05-02 23:59:59      125.599998
# 2013-05-03 23:59:59      108.127998
#                            ...
# 2021-07-02 23:59:59    33939.588699
# 2021-07-03 23:59:59    34909.259899
# 2021-07-04 23:59:59    35937.567147
# 2021-07-05 23:59:59    35284.344430
# 2021-07-06 23:59:59    35038.536363
# Name: High, Length: 2991, dtype: float64

# %%
btc.High.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
world_hr = pd.read_csv('DataAnalysis/data/world-happiness-report-2021.csv')

# %%
world_hr
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
world_hr['Healthy life expectancy']
# Out:
# 0      72.000
# 1      72.700
# 2      74.400
# 3      73.000
# 4      72.400
#         ...
# 144    48.700
# 145    59.269
# 146    61.400
# 147    56.201
# 148    52.493
# Name: Healthy life expectancy, Length: 149, dtype: float64

# %%
world_hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
# ...

# %%
world_hr.set_index('Country name', inplace=True)

# %%
world_hr
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
world_hr['Healthy life expectancy'].head(6).plot()
# Out:
# <AxesSubplot:xlabel='Country name'>

# %%
houses = pd.read_csv('DataAnalysis/data/kc_house_data.csv')

# %%
titanic = pd.read_csv('DataAnalysis/data/titanic.csv')

# %%
houses.sort_values('price', ascending= False)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 4411   2470100110  20140804T000000  5570000.0         5       5.75
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# ...           ...              ...        ...       ...        ...
# 8274   3883800011  20141105T000000    82000.0         3       1.00
# 16198  3028200080  20150324T000000    81000.0         2       1.00
# 465    8658300340  20140523T000000    80000.0         1       0.75
# 15293    40000362  20140506T000000    78000.0         2       1.00
# 1149   3421079032  20150217T000000    75000.0         1       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 7252         12050     27600     2.5           0     3  ...     13
# ...

# %%
houses.sort_values('bedrooms', ascending=False)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# ...           ...              ...        ...       ...        ...
# 19452  3980300371  20140926T000000   142000.0         0       0.00
# 8484   2310060040  20140925T000000   240000.0         0       2.50
# 875    6306400140  20140612T000000  1095000.0         0       0.00
# 8477   2569500210  20141117T000000   339950.0         0       2.50
# 9773   3374500520  20150429T000000   355000.0         0       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# ...

# %%
houses.sort_values(['bedrooms', 'bathrooms'], ascending=False).head(20)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 8546    424049043  20140811T000000   450000.0         9       7.50
# 4096   1997200215  20140507T000000   599999.0         9       4.50
# 6079   9822700190  20140808T000000  1280000.0         9       4.50
# 16844  8823900290  20150317T000000  1400000.0         9       4.00
# 4235   2902200015  20150106T000000   700000.0         9       3.00
# 18443  8823901445  20150313T000000   934000.0         9       3.00
# 4035    685000115  20141007T000000  2150000.0         8       6.00
# 1660   9126101740  20141204T000000   490000.0         8       5.00
# ...

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.sort_values('name', ascending=False)
# Out:
#       pclass  survived                                           name     sex  \
# 1268       3         0                    van Melkebeke, Mr. Philemon    male
# 1264       3         0                van Billiard, Mr. Austin Blyler    male
# 1263       3         0              van Billiard, Master. Walter John    male
# 1262       3         0            van Billiard, Master. James William    male
# 392        2         1  del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female
# ...      ...       ...                                            ...     ...
# 604        3         1                    Abelseth, Miss. Karen Marie  female
# 603        3         1               Abbott, Mrs. Stanton (Rosa Hunt)  female
# 602        3         0                    Abbott, Mr. Rossmore Edward    male
# 601        3         0                  Abbott, Master. Eugene Joseph    male
# 600        3         0                            Abbing, Mr. Anthony    male
#
# ...

# %%
titanic.sort_values('name', key=lambda col:col.str.lower())
# Out:
#       pclass  survived                              name     sex   age  sibsp  \
# 600        3         0               Abbing, Mr. Anthony    male    42      0
# 601        3         0     Abbott, Master. Eugene Joseph    male    13      0
# 602        3         0       Abbott, Mr. Rossmore Edward    male    16      1
# 603        3         1  Abbott, Mrs. Stanton (Rosa Hunt)  female    35      1
# 604        3         1       Abelseth, Miss. Karen Marie  female    16      0
# ...      ...       ...                               ...     ...   ...    ...
# 1304       3         0              Zabour, Miss. Hileni  female  14.5      1
# 1305       3         0             Zabour, Miss. Thamine  female     ?      1
# 1306       3         0         Zakarian, Mr. Mapriededer    male  26.5      0
# 1307       3         0               Zakarian, Mr. Ortin    male    27      0
# 1308       3         0                Zimmerman, Mr. Leo    male    29      0
#
# ...

# %%
world_hr
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
world_hr.sort_index()
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Afghanistan                           South Asia         2.523
# Albania               Central and Eastern Europe         5.117
# Algeria             Middle East and North Africa         4.887
# Argentina            Latin America and Caribbean         5.929
# Armenia       Commonwealth of Independent States         5.283
# ...                                          ...           ...
# Venezuela            Latin America and Caribbean         4.892
# Vietnam                           Southeast Asia         5.411
# Yemen               Middle East and North Africa         3.658
# Zambia                        Sub-Saharan Africa         4.073
# Zimbabwe                      Sub-Saharan Africa         3.145
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# ...

# %%
world_hr.shape
# Out:
# (149, 19)

# %%
# it's sorting the index upword from Z to A
world_hr.sort_index(ascending=False)
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Zimbabwe                      Sub-Saharan Africa         3.145
# Zambia                        Sub-Saharan Africa         4.073
# Yemen               Middle East and North Africa         3.658
# Vietnam                           Southeast Asia         5.411
# Venezuela            Latin America and Caribbean         4.892
# ...                                          ...           ...
# Armenia       Commonwealth of Independent States         5.283
# Argentina            Latin America and Caribbean         5.929
# Algeria             Middle East and North Africa         4.887
# Albania               Central and Eastern Europe         5.117
# Afghanistan                           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Zimbabwe                               0.058         3.259         3.030
# ...

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.pclass.value_counts()
# Out:
# 3    709
# 1    323
# 2    277
# Name: pclass, dtype: int64

# %%
titanic.pclass.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
titanic.pclass.value_counts().sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
titanic.pclass.value_counts().sort_index().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
houses.bedrooms.value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
houses.bedrooms.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
houses.bedrooms.value_counts().sort_values()
# Out:
# 11       1
# 33       1
# 10       3
# 9        6
# 0       13
# 8       13
# 7       38
# 1      199
# 6      272
# 5     1601
# 2     2760
# 4     6882
# 3     9824
# Name: bedrooms, dtype: int64

# %%
houses.bedrooms.value_counts().sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
houses.bedrooms.value_counts().sort_index()
# Out:
# 0       13
# 1      199
# 2     2760
# 3     9824
# 4     6882
# 5     1601
# 6      272
# 7       38
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
houses.bedrooms.value_counts().sort_index().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
world_hr
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
world_hr['Regional indicator']
# Out:
# Country name
# Finland            Western Europe
# Denmark            Western Europe
# Switzerland        Western Europe
# Iceland            Western Europe
# Netherlands        Western Europe
#                       ...
# Lesotho        Sub-Saharan Africa
# Botswana       Sub-Saharan Africa
# Rwanda         Sub-Saharan Africa
# Zimbabwe       Sub-Saharan Africa
# Afghanistan            South Asia
# Name: Regional indicator, Length: 149, dtype: object

# %%
world_hr.loc['Iran']
# Out:
# Regional indicator                            Middle East and North Africa
# Ladder score                                                         4.721
# Standard error of ladder score                                       0.055
# upperwhisker                                                         4.828
# lowerwhisker                                                         4.614
# Logged GDP per capita                                                9.584
# Social support                                                        0.71
# Healthy life expectancy                                               66.3
# Freedom to make life choices                                         0.608
# Generosity                                                           0.218
# Perceptions of corruption                                            0.714
# Ladder score in Dystopia                                              2.43
# ...

# %%
type(world_hr.loc['Iran'])
# Out:
# pandas.core.series.Series

# %%
type(world_hr.loc[['Iran']])
# Out:
# pandas.core.frame.DataFrame

# %%
world_hr.loc[['Iran', 'Afghanistan', 'Yemen']]
# Out:
#                         Regional indicator  Ladder score  \
# Country name
# Iran          Middle East and North Africa         4.721
# Afghanistan                     South Asia         2.523
# Yemen         Middle East and North Africa         3.658
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Iran                                   0.055         4.828         4.614
# Afghanistan                            0.038         2.596         2.449
# Yemen                                  0.070         3.794         3.521
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Iran                          9.584           0.710                   66.300
# Afghanistan                   7.695           0.463                   52.493
# Yemen                         7.578           0.832                   57.122
#
#               Freedom to make life choices  Generosity  \
# Country name
# ...

# %%
world_hr.loc[['Canada', 'Mexico', 'United States']]
# Out:
#                         Regional indicator  Ladder score  \
# Country name
# Canada               North America and ANZ         7.103
# Mexico         Latin America and Caribbean         6.317
# United States        North America and ANZ         6.951
#
#                Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Canada                                  0.042         7.185         7.021
# Mexico                                  0.053         6.420         6.213
# United States                           0.049         7.047         6.856
#
#                Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Canada                        10.776           0.926                   73.800
# Mexico                         9.859           0.831                   68.597
# United States                 11.023           0.920                   68.200
#
#                Freedom to make life choices  Generosity  \
# Country name
# ...

# %%
titanic.shape
# Out:
# (1309, 14)

# %%
# it's can be used for just one row
titanic.loc[23]
# Out:
# pclass                           1
# survived                         1
# name         Bidois, Miss. Rosalie
# sex                         female
# age                             42
# sibsp                            0
# parch                            0
# ticket                    PC 17757
# fare                       227.525
# cabin                            ?
# embarked                         C
# boat                             4
# body                             ?
# home.dest                        ?
# Name: 23, dtype: object

# %%
titanic.loc[[17,1290,895]]
# Out:
#       pclass  survived                                             name  \
# 17         1         1  Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 895        3         1                     Johnson, Miss. Eleanor Ileen
#
#          sex age  sibsp  parch    ticket      fare    cabin embarked boat  \
# 17    female  50      0      1  PC 17558  247.5208  B58 B60        C    6
# 1290  female  47      1      0    363272         7        ?        S    ?
# 895   female   1      1      1    347742   11.1333        ?        S   15
#
#      body     home.dest
# 17      ?  Montreal, PQ
# 1290    ?             ?
# 895     ?             ?

# %%
# or yo can slicing the dataset to acces the specific data
titanic.loc[5:15:2]
# Out:
#     pclass  survived                                               name  \
# 5        1         1                                Anderson, Mr. Harry
# 7        1         0                             Andrews, Mr. Thomas Jr
# 9        1         0                            Artagaveytia, Mr. Ramon
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 13       1         1                       Barber, Miss. Ellen 'Nellie'
# 15       1         0                                Baumann, Mr. John D
#
#        sex age  sibsp  parch    ticket     fare    cabin embarked boat body  \
# 5     male  48      0      0     19952    26.55      E12        S    3    ?
# 7     male  39      0      0    112050        0      A36        S    ?    ?
# 9     male  71      0      0  PC 17609  49.5042        ?        C    ?   22
# 11  female  18      1      0  PC 17757  227.525  C62 C64        C    4    ?
# 13  female  26      0      0     19877    78.85        ?        S    6    ?
# ...

# %%
world_hr
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
world_hr.sort_index(inplace=True)

# %%
world_hr
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Afghanistan                           South Asia         2.523
# Albania               Central and Eastern Europe         5.117
# Algeria             Middle East and North Africa         4.887
# Argentina            Latin America and Caribbean         5.929
# Armenia       Commonwealth of Independent States         5.283
# ...                                          ...           ...
# Venezuela            Latin America and Caribbean         4.892
# Vietnam                           Southeast Asia         5.411
# Yemen               Middle East and North Africa         3.658
# Zambia                        Sub-Saharan Africa         4.073
# Zimbabwe                      Sub-Saharan Africa         3.145
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# ...

# %%
world_hr.loc['Denmark' : 'France']
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Denmark                           Western Europe         7.620
# Dominican Republic   Latin America and Caribbean         5.545
# Ecuador              Latin America and Caribbean         5.764
# Egypt               Middle East and North Africa         4.283
# El Salvador          Latin America and Caribbean         6.061
# Estonia               Central and Eastern Europe         6.189
# Ethiopia                      Sub-Saharan Africa         4.275
# Finland                           Western Europe         7.842
# France                            Western Europe         6.690
#
#                     Standard error of ladder score  upperwhisker  \
# Country name
# Denmark                                      0.035         7.687
# Dominican Republic                           0.071         5.685
# Ecuador                                      0.057         5.875
# ...

# %%
world_hr.loc['Iran' : 'United States']
# Out:
#                                       Regional indicator  Ladder score  \
# Country name
# Iran                        Middle East and North Africa         4.721
# Iraq                        Middle East and North Africa         4.854
# Ireland                                   Western Europe         7.085
# Israel                      Middle East and North Africa         7.157
# Italy                                     Western Europe         6.483
# ...                                                  ...           ...
# Uganda                                Sub-Saharan Africa         4.636
# Ukraine               Commonwealth of Independent States         4.875
# United Arab Emirates        Middle East and North Africa         6.561
# United Kingdom                            Western Europe         7.064
# United States                      North America and ANZ         6.951
#
#                       Standard error of ladder score  upperwhisker  \
# Country name
# ...

# %%
world_hr.loc['Iran' : 'Italy']
# Out:
#                         Regional indicator  Ladder score  \
# Country name
# Iran          Middle East and North Africa         4.721
# Iraq          Middle East and North Africa         4.854
# Ireland                     Western Europe         7.085
# Israel        Middle East and North Africa         7.157
# Italy                       Western Europe         6.483
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Iran                                   0.055         4.828         4.614
# Iraq                                   0.059         4.970         4.738
# Ireland                                0.040         7.164         7.006
# Israel                                 0.034         7.224         7.090
# Italy                                  0.045         6.572         6.395
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# ...

# %%
world_hr.iloc[[20,30,57,100]]
# Out:
#                         Regional indicator  Ladder score  \
# Country name
# Cambodia                    Southeast Asia         4.830
# Croatia         Central and Eastern Europe         5.882
# Iran          Middle East and North Africa         4.721
# Nigeria                 Sub-Saharan Africa         4.759
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Cambodia                               0.067         4.963         4.698
# Croatia                                0.048         5.975         5.788
# Iran                                   0.055         4.828         4.614
# Nigeria                                0.052         4.861         4.658
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Cambodia                      8.360           0.765                   62.000
# Croatia                      10.217           0.924                   70.799
# ...

# %%
world_hr.iloc[50:60]
# Out:
#                                      Regional indicator  Ladder score  \
# Country name
# Haiti                       Latin America and Caribbean         3.615
# Honduras                    Latin America and Caribbean         5.919
# Hong Kong S.A.R. of China                     East Asia         5.477
# Hungary                      Central and Eastern Europe         5.992
# Iceland                                  Western Europe         7.554
# India                                        South Asia         3.819
# Indonesia                                Southeast Asia         5.345
# Iran                       Middle East and North Africa         4.721
# Iraq                       Middle East and North Africa         4.854
# Ireland                                  Western Europe         7.085
#
#                            Standard error of ladder score  upperwhisker  \
# Country name
# Haiti                                               0.173         3.953
# ...

# %%
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
houses.sort_index(ascending=False, inplace=True)

# %%
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21612  1523300157  20141015T000000  325000.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21608   263000018  20140521T000000  360000.0         3       2.50
# ...           ...              ...       ...       ...        ...
# 4      1954400510  20150218T000000  510000.0         3       2.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 0      7129300520  20141013T000000  221900.0         3       1.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21612         1020      1076     2.0           0     0  ...      7
# ...

# %%
houses.iloc[0:10]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 21612  1523300157  20141015T000000   325000.0         2       0.75
# 21611   291310100  20150116T000000   400000.0         3       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21604  9834201367  20150126T000000   429000.0         3       2.00
# 21603  7852140040  20140825T000000   507250.0         3       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21612         1020      1076     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# ...

# %%
houses.loc[21612:21608]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21612  1523300157  20141015T000000  325000.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21608   263000018  20140521T000000  360000.0         3       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21612         1020      1076     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21609         2310      5813     2.0           0     0  ...      8
# 21608         1530      1131     3.0           0     0  ...      8
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21612        1020              0      2008             0    98144  47.5941
# ...

# %%
houses.loc[21612:21608, ['price', 'bedrooms']]
# Out:
#           price  bedrooms
# 21612  325000.0         2
# 21611  400000.0         3
# 21610  402101.0         2
# 21609  400000.0         4
# 21608  360000.0         3

# %%
titanic.loc[40:60:2]
# Out:
#     pclass  survived                                               name  \
# 40       1         0                          Brewe, Dr. Arthur Jackson
# 42       1         1     Brown, Mrs. John Murray (Caroline Lane Lamson)
# 44       1         1                    Burns, Miss. Elizabeth Margaret
# 46       1         0                              Cairns, Mr. Alexander
# 48       1         1   Candee, Mrs. Edward (Helen Churchill Hungerford)
# 50       1         1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 52       1         0                            Carrau, Mr. Francisco M
# 54       1         1                Carter, Master. William Thornton II
# 56       1         1                         Carter, Mr. William Ernest
# 58       1         0                             Case, Mr. Howard Brown
# 60       1         0                      Cavendish, Mr. Tyrell William
#
#        sex age  sibsp  parch    ticket      fare        cabin embarked boat  \
# ...

# %%
titanic.loc[40:60:2, ['name', 'sex', 'age']]
# Out:
#                                                  name     sex age
# 40                          Brewe, Dr. Arthur Jackson    male   ?
# 42     Brown, Mrs. John Murray (Caroline Lane Lamson)  female  59
# 44                    Burns, Miss. Elizabeth Margaret  female  41
# 46                              Cairns, Mr. Alexander    male   ?
# 48   Candee, Mrs. Edward (Helen Churchill Hungerford)  female  53
# 50  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58
# 52                            Carrau, Mr. Francisco M    male  28
# 54                Carter, Master. William Thornton II    male  11
# 56                         Carter, Mr. William Ernest    male  36
# 58                             Case, Mr. Howard Brown    male  49
# 60                      Cavendish, Mr. Tyrell William    male  36

# %%
btc
# Out:
#                       SNo     Name Symbol          High           Low  \
# Date
# 2013-04-29 23:59:59     1  Bitcoin    BTC    147.488007    134.000000
# 2013-04-30 23:59:59     2  Bitcoin    BTC    146.929993    134.050003
# 2013-05-01 23:59:59     3  Bitcoin    BTC    139.889999    107.720001
# 2013-05-02 23:59:59     4  Bitcoin    BTC    125.599998     92.281898
# 2013-05-03 23:59:59     5  Bitcoin    BTC    108.127998     79.099998
# ...                   ...      ...    ...           ...           ...
# 2021-07-02 23:59:59  2987  Bitcoin    BTC  33939.588699  32770.680780
# 2021-07-03 23:59:59  2988  Bitcoin    BTC  34909.259899  33402.696536
# 2021-07-04 23:59:59  2989  Bitcoin    BTC  35937.567147  34396.477458
# 2021-07-05 23:59:59  2990  Bitcoin    BTC  35284.344430  33213.661034
# 2021-07-06 23:59:59  2991  Bitcoin    BTC  35038.536363  33599.916169
#
#                              Open         Close        Volume     Marketcap
# Date
# ...

# %%
btc.loc['2021-05-01 23:59:59': '2021-06-01 23:59:59'] ['Close']
# Out:
# Date
# 2021-05-01 23:59:59    57828.050632
# 2021-05-02 23:59:59    56631.077413
# 2021-05-03 23:59:59    57200.291223
# 2021-05-04 23:59:59    53333.537753
# 2021-05-05 23:59:59    57424.005948
# 2021-05-06 23:59:59    56396.514164
# 2021-05-07 23:59:59    57356.401877
# 2021-05-08 23:59:59    58803.775809
# 2021-05-09 23:59:59    58232.316142
# 2021-05-10 23:59:59    55859.797545
# 2021-05-11 23:59:59    56704.573058
# 2021-05-12 23:59:59    49150.533875
# 2021-05-13 23:59:59    49716.191603
# 2021-05-14 23:59:59    49880.533420
# 2021-05-15 23:59:59    46760.186561
# 2021-05-16 23:59:59    46456.058474
# 2021-05-17 23:59:59    43537.511389
# 2021-05-18 23:59:59    42909.400925
# 2021-05-19 23:59:59    37002.440466
# 2021-05-20 23:59:59    40782.738262
# 2021-05-21 23:59:59    37304.690671
# 2021-05-22 23:59:59    37536.631112
# 2021-05-23 23:59:59    34770.583623
# 2021-05-24 23:59:59    38705.978637
# 2021-05-25 23:59:59    38402.223851
# 2021-05-26 23:59:59    39294.197382
# ...

# %%
btc.loc['2021-05-01 23:59:59': '2021-06-01 23:59:59', ['Close']]
# Out:
#                             Close
# Date
# 2021-05-01 23:59:59  57828.050632
# 2021-05-02 23:59:59  56631.077413
# 2021-05-03 23:59:59  57200.291223
# 2021-05-04 23:59:59  53333.537753
# 2021-05-05 23:59:59  57424.005948
# 2021-05-06 23:59:59  56396.514164
# 2021-05-07 23:59:59  57356.401877
# 2021-05-08 23:59:59  58803.775809
# 2021-05-09 23:59:59  58232.316142
# 2021-05-10 23:59:59  55859.797545
# 2021-05-11 23:59:59  56704.573058
# 2021-05-12 23:59:59  49150.533875
# 2021-05-13 23:59:59  49716.191603
# 2021-05-14 23:59:59  49880.533420
# 2021-05-15 23:59:59  46760.186561
# 2021-05-16 23:59:59  46456.058474
# 2021-05-17 23:59:59  43537.511389
# 2021-05-18 23:59:59  42909.400925
# 2021-05-19 23:59:59  37002.440466
# 2021-05-20 23:59:59  40782.738262
# 2021-05-21 23:59:59  37304.690671
# 2021-05-22 23:59:59  37536.631112
# 2021-05-23 23:59:59  34770.583623
# 2021-05-24 23:59:59  38705.978637
# 2021-05-25 23:59:59  38402.223851
# 2021-05-26 23:59:59  39294.197382
# ...

# %%
btc.loc['2021-05-01 23:59:59': '2021-06-01 23:59:59', ['Close']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
houses.bedrooms.value_counts().loc[3]
# Out:
# 9824

# %%
houses.bedrooms.value_counts().iloc[0:5]
# Out:
# 3    9824
# 4    6882
# 2    2760
# 5    1601
# 6     272
# Name: bedrooms, dtype: int64

# %%
titanic.age.value_counts().loc['18']
# Out:
# 39

# %%
titanic.age.value_counts().loc['40']
# Out:
# 18

# %%
titanic.age.value_counts().iloc[0:5]
# Out:
# ?     263
# 24     47
# 22     43
# 21     41
# 30     40
# Name: age, dtype: int64
