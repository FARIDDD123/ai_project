# %%
import pandas as pd

# %%
carstock = pd.read_csv('DataAnalysis/data/car_stocks.csv')

# %%
titanic = pd.read_csv('DataAnalysis/data/titanic.csv')
titanic['age'] = titanic['age'].replace(['?'], [None]).astype('float')
titanic['fare'] = titanic['fare'].replace(['?'], [None]).astype('float')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: float64(2), int64(4), object(8)
# memory usage: 143.3+ KB

# %%
titanic.groupby(['pclass', 'sex'])['age'].mean()
# Out:
# pclass  sex
# 1       female    37.037594
#         male      41.029250
# 2       female    27.499191
#         male      30.815401
# 3       female    22.185307
#         male      25.962273
# Name: age, dtype: float64

# %%
df = titanic.groupby(['pclass', 'sex']).mean()

# %%
df
# Out:
#                survived        age     sibsp     parch        fare
# pclass sex
# 1      female  0.965278  37.037594  0.555556  0.472222  109.412385
#        male    0.340782  41.029250  0.340782  0.279330   69.888385
# 2      female  0.886792  27.499191  0.500000  0.650943   23.234827
#        male    0.146199  30.815401  0.327485  0.192982   19.904946
# 3      female  0.490741  22.185307  0.791667  0.731481   15.324250
#        male    0.152130  25.962273  0.470588  0.255578   12.415462

# %%
df.index
# Out:
# MultiIndex([(1, 'female'),
#             (1,   'male'),
#             (2, 'female'),
#             (2,   'male'),
#             (3, 'female'),
#             (3,   'male')],
#            names=['pclass', 'sex'])

# %%
titanic.groupby(['sex', 'age']).mean().head(50)
# Out:
#                   pclass  survived     sibsp     parch        fare
# sex    age
# female 0.1667   3.000000  1.000000  1.000000  2.000000   20.575000
#        0.7500   3.000000  1.000000  2.000000  1.000000   19.258300
#        0.9167   2.000000  1.000000  1.000000  2.000000   27.750000
#        1.0000   2.800000  0.800000  0.800000  1.400000   19.467500
#        2.0000   2.571429  0.285714  1.428571  1.428571   39.955357
#        3.0000   2.666667  0.333333  1.666667  1.333333   25.476400
#        4.0000   2.600000  1.000000  0.800000  1.200000   22.828340
#        5.0000   2.750000  1.000000  1.750000  1.250000   22.717700
#        6.0000   2.500000  0.500000  2.000000  1.500000   32.137500
#        7.0000   2.000000  1.000000  0.000000  2.000000   26.250000
#        8.0000   2.333333  0.666667  1.333333  1.333333   24.441667
#        9.0000   3.000000  0.200000  2.200000  1.600000   24.808320
#        10.0000  3.000000  0.000000  2.500000  2.000000   35.525000
# ...

# %%
states = pd.read_csv('DataAnalysis/data/state_pops.csv')

# %%
states
# Out:
#      state  year   population
# 0       AL  2012    4817528.0
# 1       AL  2010    4785570.0
# 2       AL  2011    4801627.0
# 3       AL  2009    4757938.0
# 4       AL  2013    4833722.0
# ...    ...   ...          ...
# 1267   USA  2013  316128839.0
# 1268   USA  2009  306771529.0
# 1269   USA  2010  309326295.0
# 1270   USA  2011  311582564.0
# 1271   USA  2012  313873685.0
#
# [1272 rows x 3 columns]

# %%
states.set_index(['state', 'year'], inplace=True)

# %%
states.index
# Out:
# MultiIndex([( 'AL', 2012),
#             ( 'AL', 2010),
#             ( 'AL', 2011),
#             ( 'AL', 2009),
#             ( 'AL', 2013),
#             ( 'AL', 2007),
#             ( 'AL', 2008),
#             ( 'AL', 2005),
#             ( 'AL', 2006),
#             ( 'AL', 2004),
#             ...
#             ('USA', 2004),
#             ('USA', 2005),
#             ('USA', 2006),
#             ('USA', 2007),
#             ('USA', 2008),
#             ('USA', 2013),
#             ('USA', 2009),
#             ('USA', 2010),
#             ('USA', 2011),
#             ('USA', 2012)],
#            names=['state', 'year'], length=1272)

# %%
states.sort_index()
# Out:
#             population
# state year
# AK    1990    553290.0
#       1991    570193.0
#       1992    588736.0
#       1993    599434.0
#       1994    603308.0
# ...                ...
# WY    2009    559851.0
#       2010    564222.0
#       2011    567329.0
#       2012    576626.0
#       2013    582658.0
#
# [1272 rows x 1 columns]

# %%
states.sort_index(level = 1)
# Out:
#             population
# state year
# AK    1990    553290.0
# AL    1990   4050055.0
# AR    1990   2356586.0
# AZ    1990   3684097.0
# CA    1990  29959515.0
# ...                ...
# VT    2013    626630.0
# WA    2013   6971406.0
# WI    2013   5742713.0
# WV    2013   1854304.0
# WY    2013    582658.0
#
# [1272 rows x 1 columns]

# %%
states.sort_index(level = [0,1], ascending=[False, True])
# Out:
#             population
# state year
# WY    1990    453690.0
#       1991    459260.0
#       1992    466251.0
#       1993    473081.0
#       1994    480283.0
# ...                ...
# AK    2009    698895.0
#       2010    713868.0
#       2011    723375.0
#       2012    730307.0
#       2013    735132.0
#
# [1272 rows x 1 columns]

# %%
states.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1272 entries, ('AL', 2012) to ('USA', 2012)
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   population  1262 non-null   float64
# dtypes: float64(1)
# memory usage: 15.7+ KB

# %%
states.loc['AK', 1990]
# Out:
# population    553290.0
# Name: (AK, 1990), dtype: float64

# %%
states.loc[['TX', 'AK']]
# Out:
#             population
# state year
# TX    1990  17056755.0
#       1991  17398005.0
#       1993  18161612.0
#       1992  17759738.0
#       1994  18564062.0
#       1995  18958751.0
#       1996  19340342.0
#       1998  20157531.0
#       1997  19740317.0
#       2000  20944499.0
#       1999  20558220.0
#       2001  21319622.0
#       2002  21690325.0
#       2004  22394023.0
#       2003  22030931.0
#       2005  22778123.0
#       2006  23359580.0
#       2008  24309039.0
#       2007  23831983.0
#       2013  26448193.0
#       2009  24801761.0
#       2010  25245178.0
#       2011  25640909.0
#       2012  26060796.0
# AK    1990    553290.0
#       1992    588736.0
#       1994    603308.0
#       1991    570193.0
#       1993    599434.0
#       1995    604412.0
#       1996    608569.0
#       1998    619933.0
#       1997    612968.0
#       1999    624779.0
#       2000    627963.0
#       2001    633714.0
#       2002    642337.0
#       2003    648414.0
# ...

# %%
states.loc['TX']
# Out:
#       population
# year
# 1990  17056755.0
# 1991  17398005.0
# 1993  18161612.0
# 1992  17759738.0
# 1994  18564062.0
# 1995  18958751.0
# 1996  19340342.0
# 1998  20157531.0
# 1997  19740317.0
# 2000  20944499.0
# 1999  20558220.0
# 2001  21319622.0
# 2002  21690325.0
# 2004  22394023.0
# 2003  22030931.0
# 2005  22778123.0
# 2006  23359580.0
# 2008  24309039.0
# 2007  23831983.0
# 2013  26448193.0
# 2009  24801761.0
# 2010  25245178.0
# 2011  25640909.0
# 2012  26060796.0

# %%
states.sort_index(inplace=True)

# %%
states.loc['NM':'TX']
# Out:
#             population
# state year
# NM    1990   1521574.0
#       1991   1555305.0
#       1992   1595442.0
#       1993   1636453.0
#       1994   1682398.0
# ...                ...
# TX    2009  24801761.0
#       2010  25245178.0
#       2011  25640909.0
#       2012  26060796.0
#       2013  26448193.0
#
# [312 rows x 1 columns]

# %%
states.loc[('CA', 2013)]
# Out:
# population    38332521.0
# Name: (CA, 2013), dtype: float64

# %%
states.loc[('AK', 1990) : ('AK', 1999)]
# Out:
#             population
# state year
# AK    1990    553290.0
#       1991    570193.0
#       1992    588736.0
#       1993    599434.0
#       1994    603308.0
#       1995    604412.0
#       1996    608569.0
#       1997    612968.0
#       1998    619933.0
#       1999    624779.0

# %%
states.loc[('TX', 1995) : ('TX', 2013)]
# Out:
#             population
# state year
# TX    1995  18958751.0
#       1996  19340342.0
#       1997  19740317.0
#       1998  20157531.0
#       1999  20558220.0
#       2000  20944499.0
#       2001  21319622.0
#       2002  21690325.0
#       2003  22030931.0
#       2004  22394023.0
#       2005  22778123.0
#       2006  23359580.0
#       2007  23831983.0
#       2008  24309039.0
#       2009  24801761.0
#       2010  25245178.0
#       2011  25640909.0
#       2012  26060796.0
#       2013  26448193.0

# %%
states.loc[('AK', 2011) : ('AL', 1998)]
# Out:
#             population
# state year
# AK    2011    723375.0
#       2012    730307.0
#       2013    735132.0
# AL    1990   4050055.0
#       1991   4099156.0
#       1992   4154014.0
#       1993   4214202.0
#       1994   4260229.0
#       1995   4296800.0
#       1996   4331103.0
#       1997   4367935.0
#       1998   4404701.0

# %%
states.loc[ : , 1990 , :]
# Out:
#         population
# state
# AK        553290.0
# AL       4050055.0
# AR       2356586.0
# AZ       3684097.0
# CA      29959515.0
# CO       3307618.0
# CT       3291967.0
# DC        605321.0
# DE        669567.0
# FL      13033307.0
# GA       6512602.0
# HI       1113491.0
# IA       2781018.0
# ID       1012384.0
# IL      11453316.0
# IN       5557798.0
# KS       2481349.0
# KY       3694048.0
# LA       4221532.0
# MA       6022639.0
# MD       4799770.0
# ME       1231719.0
# MI       9311319.0
# MN       4389857.0
# MO       5128880.0
# MS       2578897.0
# MT        800204.0
# NC       6664016.0
# ND        637685.0
# NE       1581660.0
# NH       1112384.0
# NJ       7762963.0
# NM       1521574.0
# NV       1220695.0
# NY      18020784.0
# OH      10864162.0
# OK       3148825.0
# OR       2860375.0
# PA      11903299.0
# PR             NaN
# RI       1005995.0
# SC       3501155.0
# SD        697101.0
# TN       4894492.0
# TX      17056755.0
# USA    249622814.0
# ...

# %%
states.loc[ : , 2013 , :].head(9).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='state'>

# %%
states.loc[ : , [2012,2013] , :].head(9).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='state,year'>

# %%
states.xs(2013, level = 'year').head(10).plot()
# Out:
# <AxesSubplot:xlabel='state'>

# %%
states.index.levels
# Out:
# FrozenList([['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'PR', 'RI', 'SC', 'SD', 'TN', 'TX', 'USA', 'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY'], [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]])

# %%
states.index.get_level_values(1)
# Out:
# Int64Index([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
#             ...
#             2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013],
#            dtype='int64', name='year', length=1272)

# %%
states.index.get_level_values(0)
# Out:
# Index(['AK', 'AK', 'AK', 'AK', 'AK', 'AK', 'AK', 'AK', 'AK', 'AK',
#        ...
#        'WY', 'WY', 'WY', 'WY', 'WY', 'WY', 'WY', 'WY', 'WY', 'WY'],
#       dtype='object', name='state', length=1272)

# %%
states.index.get_level_values(0)[192]
# Out:
# 'DE'

# %%
states.index.get_level_values(1)[198]
# Out:
# 1996

# %%
even_years = states.index.get_level_values(1) % 2 == 0

# %%
states[even_years]
# Out:
#             population
# state year
# AK    1990    553290.0
#       1992    588736.0
#       1994    603308.0
#       1996    608569.0
#       1998    619933.0
# ...                ...
# WY    2004    509106.0
#       2006    522667.0
#       2008    546043.0
#       2010    564222.0
#       2012    576626.0
#
# [636 rows x 1 columns]

# %%
states[states.population % 2 == 0]
# Out:
#             population
# state year
# AK    1990    553290.0
#       1992    588736.0
#       1993    599434.0
#       1994    603308.0
#       1995    604412.0
# ...                ...
# WY    2004    509106.0
#       2007    534876.0
#       2010    564222.0
#       2012    576626.0
#       2013    582658.0
#
# [645 rows x 1 columns]

# %%
even_pop = states.population % 2 == 0

# %%
states[even_years].head(20).unstack().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='state'>

# %%
end_with_K = states.index.get_level_values(0).str[1] == 'K'

# %%
states[end_with_K & even_years].plot()
# Out:
# <AxesSubplot:xlabel='state,year'>

# %%
states[end_with_K].index
# Out:
# MultiIndex([('AK', 1990),
#             ('AK', 1991),
#             ('AK', 1992),
#             ('AK', 1993),
#             ('AK', 1994),
#             ('AK', 1995),
#             ('AK', 1996),
#             ('AK', 1997),
#             ('AK', 1998),
#             ('AK', 1999),
#             ('AK', 2000),
#             ('AK', 2001),
#             ('AK', 2002),
#             ('AK', 2003),
#             ('AK', 2004),
#             ('AK', 2005),
#             ('AK', 2006),
#             ('AK', 2007),
#             ('AK', 2008),
#             ('AK', 2009),
#             ('AK', 2010),
#             ('AK', 2011),
#             ('AK', 2012),
#             ('AK', 2013),
#             ('OK', 1990),
#             ('OK', 1991),
#             ('OK', 1992),
#             ('OK', 1993),
#             ('OK', 1994),
#             ('OK', 1995),
#             ('OK', 1996),
#             ('OK', 1997),
#             ('OK', 1998),
#             ('OK', 1999),
#             ('OK', 2000),
# ...

# %%
df
# Out:
#                survived        age     sibsp     parch        fare
# pclass sex
# 1      female  0.965278  37.037594  0.555556  0.472222  109.412385
#        male    0.340782  41.029250  0.340782  0.279330   69.888385
# 2      female  0.886792  27.499191  0.500000  0.650943   23.234827
#        male    0.146199  30.815401  0.327485  0.192982   19.904946
# 3      female  0.490741  22.185307  0.791667  0.731481   15.324250
#        male    0.152130  25.962273  0.470588  0.255578   12.415462

# %%
df.loc[(2, 'male')]
# Out:
# survived     0.146199
# age         30.815401
# sibsp        0.327485
# parch        0.192982
# fare        19.904946
# Name: (2, male), dtype: float64

# %%
df.loc[(3, 'female')]
# Out:
# survived     0.490741
# age         22.185307
# sibsp        0.791667
# parch        0.731481
# fare        15.324250
# Name: (3, female), dtype: float64

# %%
groped_by_sex = titanic.groupby('sex').agg({
    'age' : ['min', 'max', 'mean'],
    'fare' : ['min', 'max', 'mean'],
    'survived' : ['mean']
})

# %%
groped_by_sex
# Out:
#            age                   fare                       survived
#            min   max       mean   min       max       mean      mean
# sex
# female  0.1667  76.0  28.687071  6.75  512.3292  46.198097  0.727468
# male    0.3333  80.0  30.585233  0.00  512.3292  26.154601  0.190985

# %%
groped_by_sex.index
# Out:
# Index(['female', 'male'], dtype='object', name='sex')

# %%
groped_by_sex.columns
# Out:
# MultiIndex([(     'age',  'min'),
#             (     'age',  'max'),
#             (     'age', 'mean'),
#             (    'fare',  'min'),
#             (    'fare',  'max'),
#             (    'fare', 'mean'),
#             ('survived', 'mean')],
#            )

# %%
groped_by_sex
# Out:
#            age                   fare                       survived
#            min   max       mean   min       max       mean      mean
# sex
# female  0.1667  76.0  28.687071  6.75  512.3292  46.198097  0.727468
# male    0.3333  80.0  30.585233  0.00  512.3292  26.154601  0.190985

# %%
groped_by_sex['age']['mean']
# Out:
# sex
# female    28.687071
# male      30.585233
# Name: mean, dtype: float64

# %%
groped_by_sex[('age', 'mean')]
# Out:
# sex
# female    28.687071
# male      30.585233
# Name: (age, mean), dtype: float64

# %%
groped_by_sex['fare']['mean']
# Out:
# sex
# female    46.198097
# male      26.154601
# Name: mean, dtype: float64

# %%
groped_by_sex[('fare', 'mean')].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
states.unstack()
# Out:
#         population                                                      \
# year          1990         1991         1992         1993         1994
# state
# AK        553290.0     570193.0     588736.0     599434.0     603308.0
# AL       4050055.0    4099156.0    4154014.0    4214202.0    4260229.0
# AR       2356586.0    2383144.0    2415984.0    2456303.0    2494019.0
# AZ       3684097.0    3788576.0    3915740.0    4065440.0    4245089.0
# CA      29959515.0   30470736.0   30974659.0   31274928.0   31484435.0
# CO       3307618.0    3387119.0    3495939.0    3613734.0    3724168.0
# CT       3291967.0    3302895.0    3300712.0    3309175.0    3316121.0
# DC        605321.0     600870.0     597567.0     595302.0     589240.0
# DE        669567.0     683080.0     694927.0     706378.0     717545.0
# FL      13033307.0   13369798.0   13650553.0   13927185.0   14239444.0
# GA       6512602.0    6653005.0    6817203.0    6978240.0    7157165.0
# ...

# %%
states
# Out:
#             population
# state year
# AK    1990    553290.0
#       1991    570193.0
#       1992    588736.0
#       1993    599434.0
#       1994    603308.0
# ...                ...
# WY    2009    559851.0
#       2010    564222.0
#       2011    567329.0
#       2012    576626.0
#       2013    582658.0
#
# [1272 rows x 1 columns]

# %%
states.unstack(level = 0)
# Out:
#       population                                                          \
# state         AK         AL         AR         AZ          CA         CO
# year
# 1990    553290.0  4050055.0  2356586.0  3684097.0  29959515.0  3307618.0
# 1991    570193.0  4099156.0  2383144.0  3788576.0  30470736.0  3387119.0
# 1992    588736.0  4154014.0  2415984.0  3915740.0  30974659.0  3495939.0
# 1993    599434.0  4214202.0  2456303.0  4065440.0  31274928.0  3613734.0
# 1994    603308.0  4260229.0  2494019.0  4245089.0  31484435.0  3724168.0
# 1995    604412.0  4296800.0  2535399.0  4432499.0  31696582.0  3826653.0
# 1996    608569.0  4331103.0  2572109.0  4586940.0  32018834.0  3919972.0
# 1997    612968.0  4367935.0  2601091.0  4736990.0  32486010.0  4018293.0
# 1998    619933.0  4404701.0  2626289.0  4883342.0  32987675.0  4116639.0
# 1999    624779.0  4430141.0  2651860.0  5023823.0  33499204.0  4226018.0
# 2000    627963.0  4452173.0  2678588.0  5160586.0  33987977.0  4326921.0
# ...

# %%
states.unstack(level = 'state')
# Out:
#       population                                                          \
# state         AK         AL         AR         AZ          CA         CO
# year
# 1990    553290.0  4050055.0  2356586.0  3684097.0  29959515.0  3307618.0
# 1991    570193.0  4099156.0  2383144.0  3788576.0  30470736.0  3387119.0
# 1992    588736.0  4154014.0  2415984.0  3915740.0  30974659.0  3495939.0
# 1993    599434.0  4214202.0  2456303.0  4065440.0  31274928.0  3613734.0
# 1994    603308.0  4260229.0  2494019.0  4245089.0  31484435.0  3724168.0
# 1995    604412.0  4296800.0  2535399.0  4432499.0  31696582.0  3826653.0
# 1996    608569.0  4331103.0  2572109.0  4586940.0  32018834.0  3919972.0
# 1997    612968.0  4367935.0  2601091.0  4736990.0  32486010.0  4018293.0
# 1998    619933.0  4404701.0  2626289.0  4883342.0  32987675.0  4116639.0
# 1999    624779.0  4430141.0  2651860.0  5023823.0  33499204.0  4226018.0
# 2000    627963.0  4452173.0  2678588.0  5160586.0  33987977.0  4326921.0
# ...

# %%
df['age'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='pclass,sex'>

# %%
df['age'].unstack().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='pclass'>

# %%
df
# Out:
#                survived        age     sibsp     parch        fare
# pclass sex
# 1      female  0.965278  37.037594  0.555556  0.472222  109.412385
#        male    0.340782  41.029250  0.340782  0.279330   69.888385
# 2      female  0.886792  27.499191  0.500000  0.650943   23.234827
#        male    0.146199  30.815401  0.327485  0.192982   19.904946
# 3      female  0.490741  22.185307  0.791667  0.731481   15.324250
#        male    0.152130  25.962273  0.470588  0.255578   12.415462

# %%
df['fare'].unstack().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='pclass'>

# %%
df['age'].unstack(level = 'pclass').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
titanic.groupby(['sex', 'survived'])['age'].mean().unstack().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
titanic.groupby(['sex', 'survived'])['age'].mean().unstack()
.rename(columns = 
        {0 : 'Died',
         1 : 'Survived'})
.plot(kind='bar',
      color = (['#7ed6df', '#686de0']))
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
states.groupby(level = 1).sum().plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
states.groupby(level = [1,0]).mean().head(10).unstack().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year'>
