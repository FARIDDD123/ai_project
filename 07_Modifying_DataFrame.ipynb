# %%
import pandas as pd
houses = pd.read_csv('DataAnalysis/data/kc_house_data.csv')
titanic = pd.read_csv('DataAnalysis/data/titanic.csv')
btc = pd.read_csv('DataAnalysis/data/coin_Bitcoin.csv')
countries = pd.read_csv('DataAnalysis/data/world-happiness-report-2021.csv')
netflix1 = pd.read_csv('DataAnalysis/data/netflix_titles.csv', sep='|', index_col=0)

# %%
# countries.set_index('Country name', inplace=True)
countries
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
# btc.drop(['SNo', 'Name'], axis=1)
# you can use the columns and its shurter and esyest way to do this 
btc.drop(columns=['SNo', 'Name'])
# Out:
#      Symbol                 Date          High           Low          Open  \
# 0       BTC  2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1       BTC  2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2       BTC  2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3       BTC  2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4       BTC  2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...     ...                  ...           ...           ...           ...
# 2986    BTC  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987    BTC  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988    BTC  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989    BTC  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990    BTC  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# ...

# %%
btc[['Date', 'High', 'Volume']]
# Out:
#                      Date          High        Volume
# 0     2013-04-29 23:59:59    147.488007  0.000000e+00
# 1     2013-04-30 23:59:59    146.929993  0.000000e+00
# 2     2013-05-01 23:59:59    139.889999  0.000000e+00
# 3     2013-05-02 23:59:59    125.599998  0.000000e+00
# 4     2013-05-03 23:59:59    108.127998  0.000000e+00
# ...                   ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  3.872897e+10
# 2987  2021-07-03 23:59:59  34909.259899  2.438396e+10
# 2988  2021-07-04 23:59:59  35937.567147  2.492431e+10
# 2989  2021-07-05 23:59:59  35284.344430  2.672155e+10
# 2990  2021-07-06 23:59:59  35038.536363  2.650126e+10
#
# [2991 rows x 3 columns]

# %%
btc.drop(columns=['SNo', 'Name'], inplace= True)

# %%
btc
# Out:
#      Symbol                 Date          High           Low          Open  \
# 0       BTC  2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1       BTC  2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2       BTC  2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3       BTC  2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4       BTC  2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...     ...                  ...           ...           ...           ...
# 2986    BTC  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987    BTC  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988    BTC  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989    BTC  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990    BTC  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# ...

# %%
# this axis == 0 for remove a row
# countries.drop(labels='Denmark', axis=0)

# %%
countries
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
countries.drop(['Finland','Denmark','Afghanistan'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13428\402437651.py in <module>
# ----> 1 countries.drop(['Finland','Denmark','Afghanistan'])
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
btc.sort_index(ascending=False,inplace=True)
btc.drop(2990)
# Out:
#      Symbol                 Date          High           Low          Open  \
# 2989    BTC  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2988    BTC  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2987    BTC  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2986    BTC  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2985    BTC  2021-07-01 23:59:59  35035.982712  32883.781226  35035.982712
# ...     ...                  ...           ...           ...           ...
# 4       BTC  2013-05-03 23:59:59    108.127998     79.099998    106.250000
# 3       BTC  2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 2       BTC  2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 1       BTC  2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 0       BTC  2013-04-29 23:59:59    147.488007    134.000000    134.444000
#
#              Close        Volume     Marketcap
# ...

# %%
countries
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
countries.drop(countries.index[0:3])
# Out:
#     Country name  Regional indicator  Ladder score  \
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# 5         Norway      Western Europe         7.392
# 6         Sweden      Western Europe         7.363
# 7     Luxembourg      Western Europe         7.324
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 3                             0.059         7.670         7.438
# 4                             0.027         7.518         7.410
# 5                             0.035         7.462         7.323
# 6                             0.036         7.433         7.293
# ...

# %%
titanic['species'] = 'Human'
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
houses
# Out:
#       Country          id             date     price  bedrooms  bathrooms  \
# 0         Usa  7129300520  20141013T000000  221900.0         3       1.00
# 1         Usa  6414100192  20141209T000000  538000.0         3       2.25
# 2         Usa  5631500400  20150225T000000  180000.0         2       1.00
# 3         Usa  2487200875  20141209T000000  604000.0         4       3.00
# 4         Usa  1954400510  20150218T000000  510000.0         3       2.00
# ...       ...         ...              ...       ...       ...        ...
# 21608     Usa   263000018  20140521T000000  360000.0         3       2.50
# 21609     Usa  6600060120  20150223T000000  400000.0         4       2.50
# 21610     Usa  1523300141  20140623T000000  402101.0         2       0.75
# 21611     Usa   291310100  20150116T000000  400000.0         3       2.50
# 21612     Usa  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# ...

# %%
houses.insert(0, 'Country', 'Usa')

# %%
houses

# %%
houses['Sell_price'] = houses.price * 8

# %%
houses
# Out:
#       Country          id             date     price  bedrooms  bathrooms  \
# 0         Usa  7129300520  20141013T000000  221900.0         3       1.00
# 1         Usa  6414100192  20141209T000000  538000.0         3       2.25
# 2         Usa  5631500400  20150225T000000  180000.0         2       1.00
# 3         Usa  2487200875  20141209T000000  604000.0         4       3.00
# 4         Usa  1954400510  20150218T000000  510000.0         3       2.00
# ...       ...         ...              ...       ...       ...        ...
# 21608     Usa   263000018  20140521T000000  360000.0         3       2.50
# 21609     Usa  6600060120  20150223T000000  400000.0         4       2.50
# 21610     Usa  1523300141  20140623T000000  402101.0         2       0.75
# 21611     Usa   291310100  20150116T000000  400000.0         3       2.50
# 21612     Usa  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  ...  sqft_above  \
# ...

# %%
houses.insert(3, 'New_floor', houses['floors'])

# %%
houses
# Out:
#       Country          id             date     price  bedrooms  bathrooms  \
# 0         Usa  7129300520  20141013T000000  221900.0         3       1.00
# 1         Usa  6414100192  20141209T000000  538000.0         3       2.25
# 2         Usa  5631500400  20150225T000000  180000.0         2       1.00
# 3         Usa  2487200875  20141209T000000  604000.0         4       3.00
# 4         Usa  1954400510  20150218T000000  510000.0         3       2.00
# ...       ...         ...              ...       ...       ...        ...
# 21608     Usa   263000018  20140521T000000  360000.0         3       2.50
# 21609     Usa  6600060120  20150223T000000  400000.0         4       2.50
# 21610     Usa  1523300141  20140623T000000  402101.0         2       0.75
# 21611     Usa   291310100  20150116T000000  400000.0         3       2.50
# 21612     Usa  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  ...  sqft_above  \
# ...

# %%
titanic.drop(columns='species',inplace=True)

# %%
titanic

# %%
titanic['Relatives'] = titanic.sibsp + titanic.parch

# %%
titanic.sort_values('Relatives', ascending=False)
# Out:
#       pclass  survived                                    name     sex age  \
# 1177       3         0                     Sage, Mr. Frederick    male   ?
# 1179       3         0                   Sage, Mr. John George    male   ?
# 1173       3         0            Sage, Miss. Constance Gladys  female   ?
# 1170       3         0              Sage, Master. Thomas Henry    male   ?
# 1172       3         0                         Sage, Miss. Ada  female   ?
# ...      ...       ...                                     ...     ...  ..
# 598        2         1                    Wright, Miss. Marion  female  26
# 599        2         0  Yrois, Miss. Henriette ('Mrs Harbeck')  female  24
# 600        3         0                     Abbing, Mr. Anthony    male  42
# 604        3         1             Abelseth, Miss. Karen Marie  female  16
# 1308       3         0                      Zimmerman, Mr. Leo    male  29
#
#       sibsp  parch     ticket   fare cabin embarked boat body  \
# ...

# %%
titanic[titanic.survived == 1].sort_values('Relatives',ascending=False).head(10)

# %%
solo_pass = titanic.Relatives == 0
titanic[solo_pass].sex.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='sex'>

# %%
titanic.sex.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='sex'>

# %%
houses.price / houses.sqft_living
# Out:
# 0        188.050847
# 1        209.338521
# 2        233.766234
# 3        308.163265
# 4        303.571429
#             ...
# 21608    235.294118
# 21609    173.160173
# 21610    394.216667
# 21611    250.000000
# 21612    318.627451
# Length: 21613, dtype: float64

# %%
houses.insert(4, 'House_Sqf',houses.price / houses.sqft_living )

# %%
houses.sort_values('House_Sqf', ascending=False)
# Out:
#       Country          id             date      price   House_Sqf  bedrooms  \
# 19336     Usa  6021500970  20150407T000000   874950.0  810.138889         2
# 4013      Usa   724069059  20140509T000000  2400000.0  800.000000         3
# 10446     Usa  1118000320  20150508T000000  3400000.0  798.122066         4
# 8623      Usa  6303400395  20150130T000000   325000.0  792.682927         1
# 9314      Usa  4389200610  20141201T000000   903000.0  792.105263         2
# ...       ...         ...              ...        ...         ...       ...
# 1385      Usa  3342700465  20150123T000000   250000.0   88.028169         3
# 17197     Usa  5111400086  20140512T000000   110000.0   88.000000         3
# 13825     Usa  5637200450  20141017T000000   257000.0   87.713311         5
# 3785      Usa   723049156  20140523T000000   149000.0   87.647059         3
# 18262     Usa  2891000610  20141211T000000   148900.0   87.588235         4
#
# ...

# %%
houses.sort_values('House_Sqf', ascending=False).head(50)['zipcode'].value_counts().plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
btc
# Out:
#      Symbol                 Date          High           Low          Open  \
# 2990    BTC  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
# 2989    BTC  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2988    BTC  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2987    BTC  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2986    BTC  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# ...     ...                  ...           ...           ...           ...
# 4       BTC  2013-05-03 23:59:59    108.127998     79.099998    106.250000
# 3       BTC  2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 2       BTC  2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 1       BTC  2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 0       BTC  2013-04-29 23:59:59    147.488007    134.000000    134.444000
#
#              Close        Volume     Marketcap
# ...

# %%
btc.insert(6, 'Changing' , btc.Close - btc.Open)

# %%
btc.sort_values('Changing',ascending=False)
# Out:
#      Symbol                 Date          High           Low          Open  \
# 2842    BTC  2021-02-08 23:59:59  46203.931437  38076.322807  38886.827290
# 2919    BTC  2021-04-26 23:59:59  54288.002155  48852.796843  49077.792363
# 2863    BTC  2021-03-01 23:59:59  49784.015290  45115.093115  45159.503053
# 2853    BTC  2021-02-19 23:59:59  56113.650547  50937.275722  51675.981285
# 2923    BTC  2021-04-30 23:59:59  57900.719988  53129.600877  53568.663584
# ...     ...                  ...           ...           ...           ...
# 2911    BTC  2021-04-18 23:59:59  61057.456509  52829.535926  60701.886093
# 2824    BTC  2021-01-21 23:59:59  35552.679497  30250.749639  35549.397409
# 2857    BTC  2021-02-23 23:59:59  54204.929756  45290.590268  54204.929756
# 2942    BTC  2021-05-19 23:59:59  43546.116485  30681.496912  42944.975447
# 2935    BTC  2021-05-12 23:59:59  57939.362415  49150.533875  56714.533167
#
#              Close     Changing        Volume     Marketcap
# ...

# %%
btc.set_index('Date', inplace=True)

# %%
btc
# Out:
#                     Symbol          High           Low          Open  \
# Date
# 2021-07-06 23:59:59    BTC  35038.536363  33599.916169  33723.509655
# 2021-07-05 23:59:59    BTC  35284.344430  33213.661034  35284.344430
# 2021-07-04 23:59:59    BTC  35937.567147  34396.477458  34665.564866
# 2021-07-03 23:59:59    BTC  34909.259899  33402.696536  33854.421362
# 2021-07-02 23:59:59    BTC  33939.588699  32770.680780  33549.600177
# ...                    ...           ...           ...           ...
# 2013-05-03 23:59:59    BTC    108.127998     79.099998    106.250000
# 2013-05-02 23:59:59    BTC    125.599998     92.281898    116.379997
# 2013-05-01 23:59:59    BTC    139.889999    107.720001    139.000000
# 2013-04-30 23:59:59    BTC    146.929993    134.050003    144.000000
# 2013-04-29 23:59:59    BTC    147.488007    134.000000    134.444000
#
#                             Close     Changing        Volume     Marketcap
# Date
# ...

# %%
btc.insert(6, 'Changing_2' , btc.High - btc.Low)

# %%
btc.sort_values('Changing_2',ascending=False)
# Out:
#                     Symbol          High           Low          Open  \
# Date
# 2021-05-19 23:59:59    BTC  43546.116485  30681.496912  42944.975447
# 2021-02-23 23:59:59    BTC  54204.929756  45290.590268  54204.929756
# 2021-05-12 23:59:59    BTC  57939.362415  49150.533875  56714.533167
# 2021-02-22 23:59:59    BTC  57533.389325  48967.565188  57532.738864
# 2021-05-21 23:59:59    BTC  42172.173616  33616.453884  40596.948323
# ...                    ...           ...           ...           ...
# 2015-09-17 23:59:59    BTC    230.285004    228.925995    229.076004
# 2015-06-06 23:59:59    BTC    225.718994    224.378998    225.005005
# 2015-05-28 23:59:59    BTC    237.824005    236.651993    237.257004
# 2015-10-04 23:59:59    BTC    238.968002    237.940002    238.531006
# 2013-08-07 23:59:59    BTC    106.750000    106.750000    106.750000
#
#                             Close     Changing    Changing_2        Volume  \
# Date
# ...

# %%
btc.sort_values('Changing_2',ascending=False).head(10)['Changing_2'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
countries.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
# this is for rename a columns
mapper = {'Regional indicator' : 'Regional_indicator', 'Ladder score' : 'Ladder_score'}
countries.rename(columns=mapper)
# Out:
#     Country name  Regional_indicator  Ladder_score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
countries.set_index('Country name', inplace=True)

# %%
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
# this is for changing a row and using {} 
mapper = {'Finland' : 'FINLAND', 'Denmark' : 'DENMARK'}
countries.rename(index= mapper)
# Out:
#               Regional indicator  Ladder score  \
# Country name
# FINLAND           Western Europe         7.842
# DENMARK           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# FINLAND                                0.032         7.904         7.780
# DENMARK                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...
