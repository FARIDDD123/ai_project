# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Countplots

# %%
taxis = sns.load_dataset('taxis')
diamonds = sns.load_dataset('diamonds')
tips = sns.load_dataset('tips')
penguins = sns.load_dataset('penguins')

# %%
sns.set_theme()
sns.countplot(data=penguins, x='species')
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
penguins.species.value_counts().sort_index().plot(kind='bar', color=['red','green','yellow'])
# Out:
# <AxesSubplot:>

# %%
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.countplot(data=tips, x='day', hue='smoker')
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
# titanic= pd.read_csv('DataAnalysis/data/titanic.csv')

# %%
# sns.countplot(data=titanic, x='pclass', hue='sex')
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %%
# sns.countplot(data=titanic, y='pclass', hue='sex')
# Out:
# <AxesSubplot:xlabel='count', ylabel='pclass'>

# %% [markdown]
# # StripPlot & SwarmPlot

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.stripplot(data=tips ,x='day', y='total_bill', hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(data=tips ,x='time', y='total_bill', hue='smoker')
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
sns.stripplot(data=diamonds, x='clarity', y='price', hue='cut')
# Out:
# <AxesSubplot:xlabel='clarity', ylabel='price'>

# %%
diamonds.clarity.value_counts()
# Out:
# SI1     13065
# VS2     12258
# SI2      9194
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# I1        741
# Name: clarity, dtype: int64

# %%
titanic = sns.load_dataset('titanic')

# %%
plt.figure(figsize=(12,5))
sns.swarmplot(data=titanic, x='pclass', y='age', hue='sex')
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
plt.figure(figsize=(12,5))
sns.swarmplot(data=tips, x='day', y='tip', hue='smoker')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %% [markdown]
# # BoxPlot

# %%
sns.boxenplot(data=tips, x='day', y='total_bill', hue='smoker')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sns.boxenplot(data=titanic, x='age', y='sex', hue='alive')
# Out:
# <AxesSubplot:xlabel='age', ylabel='sex'>

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
plt.figure(figsize=(12,5))
sns.boxplot(data=penguins, x='island', y='body_mass_g', hue='species')
# Out:
# <AxesSubplot:xlabel='island', ylabel='body_mass_g'>

# %%
plt.figure(figsize=(12,5))
sns.boxplot(data=penguins, x='island', y='body_mass_g', hue='species')
sns.swarmplot(data=penguins, x='island', y='body_mass_g', hue='species', color='0.7')
# Out:
# <AxesSubplot:xlabel='island', ylabel='body_mass_g'>

# %% [markdown]
# # BoxenPlots

# %%
plt.figure(figsize=(9,5))
sns.boxenplot(data=tips, x='day', y='total_bill', hue='time')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
taxis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   object
#  1   dropoff          6433 non-null   object
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: float64(5), int64(1), object(8)
# memory usage: 703.7+ KB

# %%
sns.boxenplot(data=taxis, x='payment', y='total')
# Out:
# <AxesSubplot:xlabel='payment', ylabel='total'>

# %%
sns.boxplot(data=taxis, x='payment', y='total')
# Out:
# <AxesSubplot:xlabel='payment', ylabel='total'>

# %% [markdown]
# # ViolinPlot

# %%
sns.violinplot(data=tips, x='day', y='tip', hue='smoker')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.violinplot(data=tips, x='sex', y='tip', hue='smoker')
sns.boxplot(data=tips, x='day', y='tip', hue='smoker')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.violinplot(data=tips, x='day', y='tip', hue='smoker', split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %% [markdown]
# # BarPlots

# %%
sns.barplot(data=titanic, x='pclass', y='alive')
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='alive'>

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.barplot(data=tips, x='day', y='total_bill', hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
sns.barplot(data=penguins, x='species', y='body_mass_g', hue='sex')
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
# by defult estimator is mean
plt.figure(figsize=(11,4))
sns.barplot(data=diamonds, x='clarity', y='price', hue='color', estimator=sum)
# Out:
# <AxesSubplot:xlabel='clarity', ylabel='price'>

# %%
colors=['#98DFD6','#FFDD83','#E21818','#00235B', '#245953', '#CCD5AE', '#62CDFF', '#AA77FF']
diamonds.groupby('clarity')['price'].sum().plot(kind='bar', color=colors)
# Out:
# <AxesSubplot:xlabel='clarity'>

# %%
sns.barplot(data=diamonds, x='clarity', y='price', estimator=sum)
# Out:
# <AxesSubplot:xlabel='clarity', ylabel='price'>

# %%
sns.barplot(data=diamonds, x='clarity', y='price', estimator=sum, dodge=False)
# Out:
# <AxesSubplot:xlabel='clarity', ylabel='price'>

# %%
sns.barplot(data=penguins, x='species', y='body_mass_g', hue='sex', dodge=False)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(data=titanic, x='pclass', y='survived', orient='h')
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='survived'>

# %% [markdown]
# # CatPlot

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.catplot(data=tips, x='size', y='tip', kind='bar', col='smoker', estimator=sum)

# %%
sns.catplot(data=tips, x='size', y='tip', kind='bar', col='day', row='sex', hue='smoker', estimator=sum)

# %%
sns.catplot(data=tips, x='size', y='tip', kind='box', col='day', row='sex', hue='smoker', estimator=sum)

# %%
sns.catplot(data=tips, x='size', y='tip', kind='strip', col='day', row='sex', hue='smoker', estimator=sum)

# %%
sns.catplot(data=titanic, x='who', y='age', kind='bar', col='pclass', hue='alive', estimator=sum)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
