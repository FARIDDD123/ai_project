# %%
import pandas as pd

# %%
houses = pd.read_csv('DataAnalysis/data/kc_house_data.csv')

# %%
titanic = pd.read_csv('DataAnalysis/data/titanic.csv')

# %%
netflix = pd.read_csv('DataAnalysis/data/netflix_titles.csv', sep= '|', index_col=0)

# %%
df = titanic.head()
df
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
df.sex
# Out:
# 0    female
# 1      male
# 2    female
# 3      male
# 4    female
# Name: sex, dtype: object

# %%
df.sex =='female'
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: sex, dtype: bool

# %%
df[df.sex =='female']
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#   age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0  29      0      0   24160  211.3375       B5        S    2    ?
# 2   2      1      2  113781    151.55  C22 C26        S    ?    ?
# 4  25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# 2  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
df
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
df.survived == 0
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# Name: survived, dtype: bool

# %%
df[df.survived == 0]
# Out:
#    pclass  survived                                             name     sex  \
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#   age  sibsp  parch  ticket    fare    cabin embarked boat body  \
# 2   2      1      2  113781  151.55  C22 C26        S    ?    ?
# 3  30      1      2  113781  151.55  C22 C26        S    ?  135
# 4  25      1      2  113781  151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     5 non-null      int64
#  1   survived   5 non-null      int64
#  2   name       5 non-null      object
#  3   sex        5 non-null      object
#  4   age        5 non-null      object
#  5   sibsp      5 non-null      int64
#  6   parch      5 non-null      int64
#  7   ticket     5 non-null      object
#  8   fare       5 non-null      object
#  9   cabin      5 non-null      object
#  10  embarked   5 non-null      object
#  11  boat       5 non-null      object
#  12  body       5 non-null      object
#  13  home.dest  5 non-null      object
# dtypes: int64(4), object(10)
# memory usage: 688.0+ bytes

# %%
df
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
df.survived == 0
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# Name: survived, dtype: bool

# %%
bools = [False, False, True, True, True]
df[bools]
# Out:
#    pclass  survived                                             name     sex  \
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#   age  sibsp  parch  ticket    fare    cabin embarked boat body  \
# 2   2      1      2  113781  151.55  C22 C26        S    ?    ?
# 3  30      1      2  113781  151.55  C22 C26        S    ?  135
# 4  25      1      2  113781  151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
titanic.survived == 1
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 1304    False
# 1305    False
# 1306    False
# 1307    False
# 1308    False
# Name: survived, Length: 1309, dtype: bool

# %%
titanic[titanic.survived == 1]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1261       3         1                           Turkula, Mrs. (Hedwig)
# 1277       3         1                             Vartanian, Mr. David
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked   boat  \
# ...

# %%
titanic[titanic.age == '18']
# Out:
#       pclass  survived                                               name  \
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 198        1         1  Marvin, Mrs. Daniel Warner (Mary Graham Carmic...
# 228        1         0         Penasco y Castellana, Mr. Victor de Satode
# 250        1         1                         Ryerson, Miss. Emily Borie
# 270        1         1     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)
# 289        1         1                                Taussig, Miss. Ruth
# 326        2         0                         Andrew, Mr. Edgardo Samuel
# 331        2         0                           Bailey, Mr. Percy Andrew
# 386        2         0                          Davies, Mr. Charles Henry
# 394        2         0                                Dibden, Mr. William
# 395        2         1                                Doling, Miss. Elsie
# 405        2         0                          Fahlstrom, Mr. Arne Jonas
# ...

# %%
titanic[titanic.age == '18'].age.value_counts()
# Out:
# 18    39
# Name: age, dtype: int64

# %%
titanic[titanic.age == '18'].shape
# Out:
# (39, 14)

# %%
titanic[titanic.pclass != 1]
# Out:
#       pclass  survived                                   name     sex   age  \
# 323        2         0                    Abelson, Mr. Samuel    male    30
# 324        2         1  Abelson, Mrs. Samuel (Hannah Wizosky)  female    28
# 325        2         0         Aldworth, Mr. Charles Augustus    male    30
# 326        2         0             Andrew, Mr. Edgardo Samuel    male    18
# 327        2         0               Andrew, Mr. Frank Thomas    male    25
# ...      ...       ...                                    ...     ...   ...
# 1304       3         0                   Zabour, Miss. Hileni  female  14.5
# 1305       3         0                  Zabour, Miss. Thamine  female     ?
# 1306       3         0              Zakarian, Mr. Mapriededer    male  26.5
# 1307       3         0                    Zakarian, Mr. Ortin    male    27
# 1308       3         0                     Zimmerman, Mr. Leo    male    29
#
# ...

# %%
titanic[titanic.pclass != 1].pclass.value_counts()
# Out:
# 3    709
# 2    277
# Name: pclass, dtype: int64

# %%
titanic[titanic.pclass != 1].pclass.value_counts().plot(kind= 'bar')
# Out:
# <AxesSubplot:>

# %%
houses[houses.price > 5000000]
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 1164  1247600105  20141020T000000  5110800.0         5       5.25
# 1315  7558700030  20150413T000000  5300000.0         6       6.00
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1164         8010     45517     2.0           1     4  ...     12        5990
# 1315         7390     24829     2.0           1     4  ...     12        5000
# 1448         8000     23985     2.0           0     4  ...     12        6720
# 3914        10040     37325     2.0           1     2  ...     11        7680
# ...

# %%
houses[houses.bedrooms > 8]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 4096   1997200215  20140507T000000   599999.0         9       4.50
# 4235   2902200015  20150106T000000   700000.0         9       3.00
# 6079   9822700190  20140808T000000  1280000.0         9       4.50
# 8546    424049043  20140811T000000   450000.0         9       7.50
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 16844  8823900290  20150317T000000  1400000.0         9       4.00
# 18443  8823901445  20150313T000000   934000.0         9       3.00
# 19254  8812401450  20141229T000000   660000.0        10       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 4096          3830      6988     2.5           0     0  ...      7
# ...

# %%
houses[houses.bedrooms > 8].bedrooms.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
houses[houses.bedrooms >= 8].bedrooms.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
houses[houses.bedrooms <= 3]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# 6      1321400060  20140627T000000  257500.0         3       2.25
# ...           ...              ...       ...       ...        ...
# 21607  2997800021  20150219T000000  475000.0         3       2.50
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
houses[houses.sqft_living <= 500]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 465    8658300340  20140523T000000   80000.0         1       0.75
# 860    1723049033  20140620T000000  245000.0         1       0.75
# 1168   3523029041  20141009T000000  290000.0         2       0.75
# 4203   1437500015  20140709T000000  150000.0         3       0.75
# 4651    859000110  20141002T000000  125000.0         1       1.00
# 4868   6896300380  20141002T000000  228000.0         0       1.00
# 8133   7849202585  20140904T000000  170000.0         1       1.00
# 8623   6303400395  20150130T000000  325000.0         1       0.75
# 11500  4322200105  20150331T000000  229050.0         1       1.00
# 12075  8655900162  20150219T000000  156000.0         1       0.75
# 14466  7549801385  20140612T000000  280000.0         1       0.75
# 15248  1320069249  20141020T000000  192500.0         1       1.00
# 15381  2856101479  20140701T000000  276000.0         1       0.75
# ...

# %%
houses[houses.sqft_living <= 500].sqft_living.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='sqft_living'>

# %%
netflix[netflix.release_year < 1960]
# Out:
#      show_id     type                                             title  \
# 542     s543    Movie                                             Ujala
# 1331   s1332  TV Show               Five Came Back: The Reference Films
# 1699   s1700    Movie                                   White Christmas
# 2368   s2369    Movie                                     Cairo Station
# 2369   s2370    Movie                                       Dark Waters
# 2375   s2376    Movie                                   The Blazing Sun
# 4250   s4251  TV Show                 Pioneers: First Women Filmmakers*
# 6431   s6432    Movie                             Cat on a Hot Tin Roof
# 6784   s6785    Movie                                  Forbidden Planet
# 6853   s6854    Movie                                              Gigi
# 7219   s7220    Movie                           Know Your Enemy - Japan
# 7294   s7295    Movie                                Let There Be Light
# ...

# %%
netflix[netflix.release_year < 1960].release_year.value_counts().plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
netflix[netflix.release_year.between(1940, 1945)].release_year.value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
countries = ['India', 'Japan', 'South Africa']
netflix[netflix.country.isin(countries)]
# Out:
#      show_id     type                title                 director  \
# 1         s2  TV Show        Blood & Water                      NaN
# 4         s5  TV Show         Kota Factory                      NaN
# 24       s25    Movie                Jeans               S. Shankar
# 39       s40  TV Show         Chhota Bheem                      NaN
# 50       s51  TV Show        Dharmakshetra                      NaN
# ...      ...      ...                  ...                      ...
# 8773   s8774    Movie  Yanda Kartavya Aahe             Kedar Shinde
# 8775   s8776  TV Show      Yeh Meri Family                      NaN
# 8798   s8799    Movie             Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie                Zenda           Avadhoot Gupte
# 8806   s8807    Movie               Zubaan              Mozez Singh
#
#                                                    cast       country  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# ...

# %%
netflix[netflix.country.isin(countries)].country.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
netflix.director.value_counts().head(20)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Don Michael Paul          10
# David Dhawan               9
# Yılmaz Erdoğan             8
# Lance Bangs                8
# Kunle Afolayan             8
# Quentin Tarantino          8
# Ryan Polito                8
# Troy Miller                8
# Shannon Hartman            8
# Fernando Ayllón            8
# Name: director, dtype: int64

# %%
netflix[netflix.director.isin(['Rajiv Chilaka', 'Suhas Kadav', 'Don Michael Paul'])]
# Out:
#      show_id   type                                              title  \
# 406     s407  Movie                       Chhota Bheem - Neeli Pahaadi
# 407     s408  Movie                              Chhota Bheem & Ganesh
# 408     s409  Movie                 Chhota Bheem & Krishna: Mayanagari
# 409     s410  Movie  Chhota Bheem & Krishna: Pataliputra- City of t...
# 410     s411  Movie                 Chhota Bheem And The Broken Amulet
# 411     s412  Movie             Chhota Bheem And The Crown of Valhalla
# 412     s413  Movie               Chhota Bheem and the Incan Adventure
# 413     s414  Movie                Chhota Bheem and The ShiNobi Secret
# 414     s415  Movie                           Chhota Bheem Aur Hanuman
# 415     s416  Movie                           Chhota Bheem aur Krishna
# 416     s417  Movie                Chhota Bheem aur Krishna vs Zimbara
# 419     s420  Movie                      Chhota Bheem: Bheem vs Aliens
# ...

# %%
netflix[netflix.director.isin(['Rajiv Chilaka', 'Suhas Kadav', 'Don Michael Paul'])].director.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='director'>

# %%
netflix.duration.value_counts().head(20)
# Out:
# 1 Season     1793
# 2 Seasons     425
# 3 Seasons     199
# 90 min        152
# 94 min        146
# 97 min        146
# 93 min        146
# 91 min        144
# 95 min        137
# 96 min        130
# 92 min        129
# 102 min       122
# 98 min        120
# 99 min        118
# 101 min       116
# 88 min        116
# 103 min       114
# 106 min       111
# 100 min       108
# 89 min        106
# Name: duration, dtype: int64

# %%
movie_duration = ['1 Season','2 Seasons','3 Seasons','96 min','90 min','100 min','88 min']
netflix[netflix.duration.isin(movie_duration)].duration.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
movie_type = netflix.type == 'TV Show'
movie_country = netflix.country == 'India'
netflix[movie_type & movie_country]
# Out:
#      show_id     type                               title director  \
# 4         s5  TV Show                        Kota Factory      NaN
# 39       s40  TV Show                        Chhota Bheem      NaN
# 50       s51  TV Show                       Dharmakshetra      NaN
# 66       s67  TV Show       Raja Rasoi Aur Anya Kahaniyan      NaN
# 69       s70  TV Show      Stories by Rabindranath Tagore      NaN
# ...      ...      ...                                 ...      ...
# 8173   s8174  TV Show                           Thackeray      NaN
# 8235   s8236  TV Show                         The Calling    Bumpy
# 8321   s8322  TV Show  The Golden Years with Javed Akhtar      NaN
# 8349   s8350  TV Show              The House That Made Me      NaN
# 8775   s8776  TV Show                     Yeh Meri Family      NaN
#
#                                                    cast country  \
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
# ...

# %%
houses[(houses.waterfront == 1) & (houses.price > 3000000)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 300    3225069065  20140624T000000  3075000.0         4       5.00
# 656    3760500116  20141120T000000  3070000.0         3       2.50
# 1164   1247600105  20141020T000000  5110800.0         5       5.25
# 1315   7558700030  20150413T000000  5300000.0         6       6.00
# 2085   8106100105  20141114T000000  3850000.0         4       4.25
# 2444   7524900003  20141210T000000  3278000.0         2       1.75
# 2626   7738500731  20140815T000000  4500000.0         5       5.50
# 2864   4114601570  20141118T000000  3600000.0         3       3.25
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 6508   4217402115  20150421T000000  3650000.0         6       4.75
# 7313   4131900066  20140825T000000  3100000.0         3       3.00
# 7989   9362000040  20140623T000000  3400000.0         3       4.50
# 8092   1924059029  20140617T000000  4668000.0         5       6.75
# ...

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
houses[(houses.view == 4) & (houses.grade > 10) & (houses.sqft_living <= 3000)]
# Out:
#              id             date      price  bedrooms  bathrooms  sqft_living  \
# 4013  724069059  20140509T000000  2400000.0         3       2.25         3000
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 4013     11665     1.5           1     4  ...     11        3000
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 4013              0      2001             0    98075  47.5884 -122.086
#
#       sqft_living15  sqft_lot15
# 4013           3000       15959
#
# [1 rows x 21 columns]

# %%
year_built = houses.yr_built >= 2014
year_renovated = houses.yr_renovated >= 2014
recante = houses[year_built | year_renovated]
recante.sort_values('yr_renovated')
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 42     7203220400  20140707T000000   861990.0         5       2.75
# 20563   715010110  20140804T000000  1240420.0         5       3.25
# 20567  6926700654  20140921T000000   700000.0         2       2.00
# 20569  8895800110  20140805T000000  1299890.0         5       4.00
# 20576  3277801592  20140925T000000   479950.0         3       2.00
# ...           ...              ...        ...       ...        ...
# 2295   8712100320  20140728T000000   585000.0         5       2.75
# 3156   6821100195  20150331T000000   830000.0         4       3.00
# 11599  7284900030  20140522T000000   850000.0         4       3.25
# 16683  5113000420  20150320T000000   420000.0         4       2.75
# 11633   461004730  20150406T000000   717000.0         3       1.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 42            3595      5639     2.0           0     0  ...      9
# ...

# %%
netflix.director.value_counts()
# Out:
# Rajiv Chilaka                     19
# Raúl Campos, Jan Suter            18
# Marcus Raboy                      16
# Suhas Kadav                       16
# Jay Karas                         14
#                                   ..
# Raymie Muzquiz, Stu Livingston     1
# Joe Menendez                       1
# Eric Bross                         1
# Will Eisenberg                     1
# Mozez Singh                        1
# Name: director, Length: 4528, dtype: int64

# %%
rajiv = netflix.director == 'Rajiv Chilaka'
mozez = netflix.director == 'Mozez Singh'
reles_yr = netflix.release_year.between(2015, 2018)
netflix[(rajiv | mozez) & reles_yr]
# Out:
#      show_id   type                  title       director  \
# 6297   s6298  Movie              Bheemayan  Rajiv Chilaka
# 6645   s6646  Movie  Dragonkala Ka Rahasya  Rajiv Chilaka
# 8806   s8807  Movie                 Zubaan    Mozez Singh
#
#                                                    cast country  \
# 6297                                                NaN     NaN
# 6645                                                NaN     NaN
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...   India
#
#          date_added  release_year rating duration  \
# 6297   May 10, 2019          2018   TV-Y   63 min
# 6645  June 18, 2019          2018   TV-Y   68 min
# 8806  March 2, 2019          2015  TV-14  111 min
#
#                                            listed_in  \
# 6297                        Children & Family Movies
# 6645                        Children & Family Movies
# 8806  Dramas, International Movies, Music & Musicals
#
# ...

# %%
netflix[netflix.director.isna()]
# Out:
#      show_id     type                                title director  \
# 1         s2  TV Show                        Blood & Water      NaN
# 3         s4  TV Show                Jailbirds New Orleans      NaN
# 4         s5  TV Show                         Kota Factory      NaN
# 10       s11  TV Show  Vendetta: Truth, Lies and The Mafia      NaN
# 14       s15  TV Show      Crime Stories: India Detectives      NaN
# ...      ...      ...                                  ...      ...
# 8795   s8796  TV Show                      Yu-Gi-Oh! Arc-V      NaN
# 8796   s8797  TV Show                           Yunus Emre      NaN
# 8797   s8798  TV Show                            Zak Storm      NaN
# 8800   s8801  TV Show                   Zindagi Gulzar Hai      NaN
# 8803   s8804  TV Show                          Zombie Dumb      NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %% [markdown]
# # tilda ~
# #### it's turn tha value back all the value left

# %% [markdown]
# # isna
# * isna this is for NAN value in datsets
# # notna
# * notna this is upsite of the isna

# %%
nan = netflix.director.isna()
netflix[~nan]
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# ...                             ...
# ...

# %%
nan_cast = netflix.cast.isna()
netflix[nan & nan_cast]
# Out:
#      show_id     type                                title director cast  \
# 3         s4  TV Show                Jailbirds New Orleans      NaN  NaN
# 10       s11  TV Show  Vendetta: Truth, Lies and The Mafia      NaN  NaN
# 14       s15  TV Show      Crime Stories: India Detectives      NaN  NaN
# 66       s67  TV Show        Raja Rasoi Aur Anya Kahaniyan      NaN  NaN
# 69       s70  TV Show       Stories by Rabindranath Tagore      NaN  NaN
# ...      ...      ...                                  ...      ...  ...
# 8605   s8606  TV Show                            Top Grier      NaN  NaN
# 8609   s8610  TV Show                               Towies      NaN  NaN
# 8700   s8701  TV Show                    Wartime Portraits      NaN  NaN
# 8755   s8756  TV Show                    Women Behind Bars      NaN  NaN
# 8803   s8804  TV Show                          Zombie Dumb      NaN  NaN
#
#             country          date_added  release_year rating   duration  \
# ...

# %%
netflix[(netflix.country.notna()) & (netflix.director.notna())]
# Out:
#      show_id     type                          title             director  \
# 0         s1    Movie           Dick Johnson Is Dead      Kirsten Johnson
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
women = titanic.sex == 'female'
titanic[women].survived.value_counts()
# Out:
# 1    339
# 0    127
# Name: survived, dtype: int64

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 143.3+ KB

# %%
titanic[titanic.sex == 'female'].survived.value_counts()
# Out:
# 1    339
# 0    127
# Name: survived, dtype: int64

# %%
titanic[women].survived.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='survived'>

# %%
# this is for man use the tilda~ for upside the women
titanic[~women].survived.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='survived'>

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
houses[houses.price > 3000000].zipcode.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
houses[houses.price > 3000000].zipcode.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='zipcode'>
