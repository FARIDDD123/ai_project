# %%
import pandas as pd
houses = pd.read_csv('DataAnalysis/data/kc_house_data.csv')
titanic = pd.read_csv('DataAnalysis/data/titanic.csv')
btc = pd.read_csv('DataAnalysis/data/coin_Bitcoin.csv')
countries = pd.read_csv('DataAnalysis/data/world-happiness-report-2021.csv', index_col=0 )
netflix = pd.read_csv('DataAnalysis/data/netflix_titles.csv', sep= '|' , index_col= 0)

# %%
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
# replace columns
titanic.sex.replace({'female' : 'Female', 'male' : 'Male'}, inplace=True)
# or you can use like list
# titanic.sex.replace(['female' , 'male'], ['Female', 'Male'], inplace=True)

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# # None
# * for replace enything with none you most use []

# %%
# replace '?' with None
titanic.age.replace(['?'],[None], inplace=True)
titanic.age.value_counts()
# Out:
# 24        47
# 22        43
# 21        41
# 30        40
# 18        39
#           ..
# 0.3333     1
# 22.5       1
# 70.5       1
# 0.6667     1
# 26.5       1
# Name: age, Length: 98, dtype: int64

# %%
# value_counts() dosen't show you none value for this you most use "dropna = False" for value_counts()
titanic.age.value_counts(dropna=False)
# Out:
# None      263
# 24         47
# 22         43
# 21         41
# 30         40
#          ...
# 66          1
# 0.6667      1
# 76          1
# 67          1
# 26.5        1
# Name: age, Length: 99, dtype: int64

# %%
countries.loc['Iran']
# Out:
# Regional indicator                            Middle East and North Africa
# Ladder score                                                         4.721
# Standard error of ladder score                                       0.055
# upperwhisker                                                         4.828
# lowerwhisker                                                         4.614
# Logged GDP per capita                                                9.584
# Social support                                                        0.71
# Healthy life expectancy                                               66.3
# Freedom to make life choices                                         0.608
# Generosity                                                           0.218
# Perceptions of corruption                                            0.714
# Ladder score in Dystopia                                              2.43
# ...

# %%
countries.loc['Iran', ['Healthy life expectancy','Social support', 'Regional indicator']]
# Out:
# Healthy life expectancy                            66.3
# Social support                                     0.71
# Regional indicator         Middle East and North Africa
# Name: Iran, dtype: object

# %%
countries.loc['Iraq',['Healthy life expectancy','Social support', 'Regional indicator']]
# Out:
# Healthy life expectancy                          60.583
# Social support                                    0.746
# Regional indicator         Middle East and North Africa
# Name: Iraq, dtype: object

# %%
countries.loc['Denmark',['Healthy life expectancy','Social support', 'Regional indicator']]
# Out:
# Healthy life expectancy              72.7
# Social support                      0.954
# Regional indicator         Western Europe
# Name: Denmark, dtype: object

# %%
countries.loc[['Iran','Iraq', 'Denmark'],['Healthy life expectancy','Social support', 'Regional indicator']]
# Out:
#               Healthy life expectancy  Social support  \
# Country name
# Iran                           66.300           0.710
# Iraq                           60.583           0.746
# Denmark                        72.700           0.954
#
#                         Regional indicator
# Country name
# Iran          Middle East and North Africa
# Iraq          Middle East and North Africa
# Denmark                     Western Europe

# %%
countries.loc[['Denmark', 'Norway', 'Sweden'], ['Regional indicator']] = 'Scandinavia'

# %%
countries.loc[['Denmark', 'Norway', 'Sweden'], ['Regional indicator']]
# Out:
#              Regional indicator
# Country name
# Denmark             Scandinavia
# Norway              Scandinavia
# Sweden              Scandinavia

# %%
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark              Scandinavia         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
countries.loc[['Finland','Iceland','Norway','Sweden','Denmark'], ['Regional indicator', 'IsCold']] = ['Nordic Countries', 'yes!']

# %%
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland         Nordic Countries         7.842
# Denmark         Nordic Countries         7.620
# Switzerland       Western Europe         7.571
# Iceland         Nordic Countries         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
countries.loc[['Finland','Iceland','Norway','Sweden','Denmark'], ['Regional indicator', 'IsCold']]
# Out:
#              Regional indicator IsCold
# Country name
# Finland        Nordic Countries   yes!
# Iceland        Nordic Countries   yes!
# Norway         Nordic Countries   yes!
# Sweden         Nordic Countries   yes!
# Denmark        Nordic Countries   yes!

# %%
many_bedrooms = houses.bedrooms >= 10
houses.loc[many_bedrooms]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 19254  8812401450  20141229T000000   660000.0        10       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 8757          3000      4960     2.0           0     0  ...      7
# 13314         4590     10920     1.0           0     2  ...      9
# 15161         3610     11914     2.0           0     0  ...      7
# 15870         1620      6000     1.0           0     0  ...      7
# 19254         2920      3745     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 8757         2400            600      1918          1999    98106  47.5560
# ...

# %%
houses.loc[many_bedrooms, ['bedrooms']]
# Out:
#        bedrooms
# 8757         11
# 13314        10
# 15161        10
# 15870        33
# 19254        10

# %%
houses.loc[many_bedrooms, ['bedrooms']] = 'Wow To Many!'

# %%
houses.loc[many_bedrooms]
# Out:
#                id             date      price      bedrooms  bathrooms  \
# 8757   1773100755  20140821T000000   520000.0  Wow To Many!       3.00
# 13314   627300145  20140814T000000  1148000.0  Wow To Many!       5.25
# 15161  5566100170  20141029T000000   650000.0  Wow To Many!       2.00
# 15870  2402100895  20140625T000000   640000.0  Wow To Many!       1.75
# 19254  8812401450  20141229T000000   660000.0  Wow To Many!       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 8757          3000      4960     2.0           0     0  ...      7
# 13314         4590     10920     1.0           0     2  ...      9
# 15161         3610     11914     2.0           0     0  ...      7
# 15870         1620      6000     1.0           0     0  ...      7
# 19254         2920      3745     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# ...

# %%
houses.grade.sort_values(ascending=False).value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
high_quality = houses.grade >+ 12
good_view = houses.view == 4
houses[high_quality & good_view]
# Out:
#                id             date      price bedrooms  bathrooms  \
# 9254   9208900037  20140919T000000  6885000.0        6       7.75
# 14556  2303900035  20140611T000000  2888000.0        5       6.25
# 19017  2303900100  20140911T000000  3800000.0        3       4.25
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 9254          9890     31374     2.0           0     4  ...     13
# 14556         8670     64033     2.0           0     4  ...     13
# 19017         5510     35000     2.0           0     4  ...     13
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 9254         8860           1030      2001             0    98039  47.6305
# 14556        6120           2550      1965          2003    98177  47.7295
# 19017        4910            600      1997             0    98177  47.7296
#
#           long  sqft_living15  sqft_lot15
# 9254  -122.240           4540       42730
# ...

# %%
houses['Luxre_level'] = 'Normal level'

# %%
houses.loc[good_view & high_quality, ['Luxre_level']] = 'Ultra level'

# %%
houses.loc[good_view & high_quality]
# Out:
#                id             date      price bedrooms  bathrooms  \
# 9254   9208900037  20140919T000000  6885000.0        6       7.75
# 14556  2303900035  20140611T000000  2888000.0        5       6.25
# 19017  2303900100  20140911T000000  3800000.0        3       4.25
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 9254          9890     31374     2.0           0     4  ...        8860
# 14556         8670     64033     2.0           0     4  ...        6120
# 19017         5510     35000     2.0           0     4  ...        4910
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 9254            1030      2001             0    98039  47.6305 -122.240
# 14556           2550      1965          2003    98177  47.7295 -122.372
# 19017            600      1997             0    98177  47.7296 -122.370
#
#        sqft_living15  sqft_lot15  Luxre_level
# 9254            4540       42730  Ultra level
# ...

# %%
good_view2 = houses.view.between(2,3)
mid_quality = houses.grade.between(8,12)
houses.loc[good_view2 & mid_quality, ['Luxre_level']] = 'Mid level'

# %%
houses.Luxre_level.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
