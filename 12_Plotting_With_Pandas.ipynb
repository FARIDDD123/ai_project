# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
titanic = pd.read_csv('DataAnalysis/data/titanic.csv')
titanic['age'] = pd.to_numeric(titanic['age'], errors='coerce')

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
houses = pd.read_csv('DataAnalysis/data/kc_house_data.csv')

# %%
ufos = pd.read_csv('DataAnalysis/data/nuforc_reports.csv', parse_dates=['date_time', 'posted'])

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  datetime64[ns]
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
# dtypes: datetime64[ns](2), float64(2), object(8)
# memory usage: 8.1+ MB

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
houses[['sqft_living', 'sqft_lot']].sort_values('sqft_living', ascending=False).head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('ggplot')

# %%
plt.figure(figsize=(9,4))
titanic.pclass.value_counts().plot(kind='bar')
plt.title('Bar Plot')
# Out:
# Text(0.5, 1.0, 'Bar Plot')

# %%
ufos['Month'] = ufos.date_time.dt.month

# %%
ufos.head()
# Out:
#                                              summary        city state  \
# 0  My wife was driving southeast on a fairly popu...     Chester    VA
# 1  I think that I may caught a UFO on the NBC Nig...  Rocky Hill    CT
# 2  I woke up late in the afternoon 3:30-4pm. I we...         NaN   NaN
# 3  I was driving towards the intersection of fall...      Ottawa    ON
# 4  In Peoria Arizona, I saw a cigar shaped craft ...      Peoria    NY
#
#             date_time     shape     duration  \
# 0 2019-12-12 18:43:00     light    5 seconds
# 1 2019-03-22 18:30:00    circle  3-5 seconds
# 2                 NaT       NaN          NaN
# 3 2019-04-17 02:00:00  teardrop   10 seconds
# 4 2009-03-15 18:00:00     cigar    2 minutes
#
#                                                stats  \
# 0  Occurred : 12/12/2019 18:43  (Entered as : 12/...
# 1  Occurred : 3/22/2019 18:30  (Entered as : 03/2...
# 2  Occurred : 4/1/2019 15:45  (Entered as : April...
# ...

# %%
sightings = ufos.Month.value_counts().sort_index()
sightings.plot(kind='bar', title = 'Ufos')
plt.xlabel('Month', fontsize =24, color= 'blue')
plt.ylabel('Num sightings')
# Out:
# Text(0, 0.5, 'Num sightings')

# %%
sightings
# Out:
# 1.0      5979
# 2.0      4559
# 3.0      5494
# 4.0      5817
# 5.0      6063
# 6.0      8357
# 7.0     10682
# 8.0      8997
# 9.0      8498
# 10.0     8371
# 11.0     7596
# 12.0     6525
# Name: Month, dtype: int64

# %%
month_dict = {1: 'Jan',
            2: 'Feb',
            3: 'Mar',
            4: 'Apr',
            5: 'May',
            6: 'Jun',
            7: 'Jul',
            8: 'Aug',
            9: 'Sep',
            10: 'Oct',
            11: 'Nov',
            12: 'Dec'
}

# %%
sightings.rename(month_dict).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
salaries = pd.read_csv('DataAnalysis/data/Salaries.csv', low_memory=False)

# %%
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
salaries['BasePay'] = pd.to_numeric(salaries['BasePay'], errors='coerce').fillna(0)
salaries['OvertimePay'] = pd.to_numeric(salaries['OvertimePay'], errors='coerce').fillna(0)
salaries['OtherPay'] = pd.to_numeric(salaries['OtherPay'], errors='coerce').fillna(0)

# %%
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148654 non-null  float64
#  4   OvertimePay       148654 non-null  float64
#  5   OtherPay          148654 non-null  float64
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(6), int64(2), object(5)
# memory usage: 14.7+ MB

# %%
df = salaries[['EmployeeName', 'BasePay', 'OvertimePay', 'OtherPay']]

# %%
df.set_index('EmployeeName', inplace=True)

# %%
df.head(10).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='EmployeeName'>

# %%
df.head(10).plot(kind='bar', stacked = True)
# Out:
# <AxesSubplot:xlabel='EmployeeName'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148654 entries, NATHANIEL FORD to Joe Lopez
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   BasePay      148654 non-null  float64
#  1   OvertimePay  148654 non-null  float64
#  2   OtherPay     148654 non-null  float64
# dtypes: float64(3)
# memory usage: 4.5+ MB

# %%
df.BasePay.sort_values(ascending=False).head(10).plot.bar(color = 'Blue', title = 'Heghest Pay')
# Out:
# <AxesSubplot:title={'center':'Heghest Pay'}, xlabel='EmployeeName'>

# %%
df.sort_values('OvertimePay', ascending=False).head().plot.barh()
# Out:
# <AxesSubplot:ylabel='EmployeeName'>

# %%
df.OvertimePay.sort_values(ascending=False).head().plot.barh()
# Out:
# <AxesSubplot:ylabel='EmployeeName'>

# %%
df.sort_values('OvertimePay', ascending=False).head().plot.barh(stacked = True)
# Out:
# <AxesSubplot:ylabel='EmployeeName'>

# %%
df.BasePay.plot.hist(bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.hist(bins=100, color= ['#9b59b6','#f1c40f', '#34495e'])
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.hist(bins=50, color = '#9b59b6')
# Out:
# array([[<AxesSubplot:title={'center':'BasePay'}>,
#         <AxesSubplot:title={'center':'OvertimePay'}>],
#        [<AxesSubplot:title={'center':'OtherPay'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# # Box Plot

# %%
df.plot(kind='box', showfliers= False)
# Out:
# <AxesSubplot:>

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
houses.bedrooms.plot(kind='box', showfliers= False)
# Out:
# <AxesSubplot:>

# %%
houses[['bedrooms', 'bathrooms']].boxplot(showfliers= False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Line Plots

# %%
ufos.Month.value_counts().sort_index().plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Scatter plots

# %%
houses.plot.scatter(x= 'bedrooms', y= 'bathrooms')
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='bathrooms'>

# %%
houses.plot.scatter(x= 'bedrooms', y= 'bathrooms', marker = 'X', color = '#8e44ad')
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='bathrooms'>

# %%
ufos[ufos['state'] == 'NY'].Month.value_counts().sort_index().plot(label= 'NY')
ufos[ufos['state'] == 'TX'].Month.value_counts().sort_index().plot(label= 'TX')
plt.legend(loc = 2)
plt.title('Ufos Sightings By State')
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  datetime64[ns]
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
#  12  Month           86938 non-null  float64
# dtypes: datetime64[ns](2), float64(3), object(8)
# memory usage: 8.7+ MB

# %%
ufos['year'] = ufos.date_time.dt.year

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  datetime64[ns]
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
#  12  Month           86938 non-null  float64
#  13  year            86938 non-null  float64
# dtypes: datetime64[ns](2), float64(4), object(8)
# memory usage: 9.4+ MB

# %%
ufos['shape'].value_counts()
# Out:
# light        18230
# circle       10130
# triangle      7910
# fireball      7095
# unknown       6182
# sphere        6065
# other         5749
# disk          4522
# oval          3857
# formation     2842
# changing      2112
# cigar         1990
# flash         1675
# rectangle     1597
# cylinder      1374
# diamond       1273
# chevron        953
# teardrop       767
# egg            666
# cone           349
# cross          289
# Name: shape, dtype: int64

# %%
plt.figure(figsize=(11,5))
ufos[ufos['shape'] == 'circle']['year'].value_counts().sort_index().plot(label = 'circle')
ufos[ufos['shape'] == 'light']['year'].value_counts().sort_index().plot(label = 'light')
ufos[ufos['shape'] == 'triangle']['year'].value_counts().sort_index().plot(label = 'triangel')
ufos[ufos['shape'] == 'fireball']['year'].value_counts().sort_index().plot(label = 'fireball')
ufos[ufos['shape'] == 'formation']['year'].value_counts().sort_index().plot(label = 'formation')
plt.legend(shadow = True,)
plt.title('Ufos Sightings By Shape')
plt.xlim(2000, 2018)
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# # Subplots

# %%
df.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot(kind='hist',bins= 100, subplots= True, figsize = (7,9))
plt.tight_layout()

# %%
df.plot(kind='hist',bins= 100, subplots= True, sharex= False, layout=(1,3), figsize = (12,3))
plt.tight_layout()

# %%
axs = df.plot(kind='hist',bins= 100, subplots= True, sharex= False, layout=(1,3), figsize = (12,3))
plt.tight_layout()
axs[0][0].set_title('First')
axs[0][1].set_title('Middle')
axs[0][2].set_title('Third')
axs[0][2].set_xlim(0, 30000)
axs[0][1].set_xlim(0, 30000)
# Out:
# (0.0, 30000.0)

# %%
fig, axs = plt.subplots(1,2)
plt.figure(figsize=(10,10))
ufos.year.value_counts().sort_index().plot(ax = axs[0])
axs[0].set_title('Sighting By Year')
ufos.Month.value_counts().sort_index().plot(kind='bar', ax = axs[1])
axs[1].set_title('Sighting By Month')
# Out:
# Text(0.5, 1.0, 'Sighting By Month')

# %%
month = {1: 'Jan',
            2: 'Feb',
            3: 'Mar',
            4: 'Apr',
            5: 'May',
            6: 'Jun',
            7: 'Jul',
            8: 'Aug',
            9: 'Sep',
            10: 'Oct',
            11: 'Nov',
            12: 'Dec'
}

# %%
fig, axs = plt.subplots(2,3, figsize = (14,8))
fig.suptitle('Ufo Sightings By Month', fontsize= 14)
ufos[ufos.year == 2014].Month.value_counts().sort_index().rename(month).plot(kind='bar', color = '#1abc9c', ax = axs[0][0], title = '2014')
ufos[ufos.year == 2015].Month.value_counts().sort_index().rename(month).plot(kind='bar', color = '#3498db', ax = axs[0][1], title = '2015')
ufos[ufos.year == 2016].Month.value_counts().sort_index().rename(month).plot(kind='bar', color = '#9b59b6', ax = axs[0][2], title = '2016')
ufos[ufos.year == 2017].Month.value_counts().sort_index().rename(month).plot(kind='bar', color = '#f1c40f', ax = axs[1][0], title = '2017')
ufos[ufos.year == 2018].Month.value_counts().sort_index().rename(month).plot(kind='bar', color = '#30336b', ax = axs[1][1], title = '2018')
ufos[ufos.year == 2019].Month.value_counts().sort_index().rename(month).plot(kind='bar', color = '#6ab04c', ax = axs[1][2], title = '2019')
plt.tight_layout()
