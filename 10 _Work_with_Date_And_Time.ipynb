# %%
import pandas as pd

# %%
pd.to_datetime('2020, 12, 03')
# Out:
# Timestamp('2020-12-03 00:00:00')

# %%
pd.to_datetime('2020/ 12/ 03')
# Out:
# Timestamp('2020-12-03 00:00:00')

# %%
pd.to_datetime('2020-03-12')
# Out:
# Timestamp('2020-03-12 00:00:00')

# %%
pd.to_datetime('2020, October, 03')
# Out:
# Timestamp('2020-10-03 00:00:00')

# %%
pd.to_datetime('2020, October, 12st')
# Out:
# Timestamp('2020-10-12 00:00:00')

# %%
pd.to_datetime('2020, October, 03 11pm' )
# Out:
# Timestamp('2020-10-03 23:00:00')

# %%
pd.to_datetime('2020, October, 03 14:23:12')
# Out:
# Timestamp('2020-10-03 14:23:12')

# %%
pd.to_datetime('4/7/22')
# Out:
# Timestamp('2022-04-07 00:00:00')

# %%
pd.to_datetime('4/7/22', dayfirst=True)
# Out:
# Timestamp('2022-07-04 00:00:00')

# %%
pd.to_datetime('22/10/11')
# Out:
# Timestamp('2011-10-22 00:00:00')

# %%
pd.to_datetime('22/10/11', yearfirst=True)
# Out:
# Timestamp('2022-10-11 00:00:00')

# %%
pd.to_datetime('22/10/11', yearfirst=True, dayfirst=True)
# Out:
# Timestamp('2022-11-10 00:00:00')

# %%
pd.to_datetime('22/03/12')
# Out:
# Timestamp('2012-03-22 00:00:00')

# %%
pd.to_datetime('22/03/12', format='%y/%d/%m')
# Out:
# Timestamp('2022-12-03 00:00:00')

# %%
meetings = ['Dec/11/2009 name', 'Jan/04/2010 name', 'Mar/19/2020 name', 'Apr/13/1964 name']

# %%
meetings
# Out:
# ['Dec/11/2009 name',
#  'Jan/04/2010 name',
#  'Mar/19/2020 name',
#  'Apr/13/1964 name']

# %%
pd.to_datetime(meetings, format='%b/%d/%Y name')
# Out:
# DatetimeIndex(['2009-12-11', '2010-01-04', '2020-03-19', '1964-04-13'], dtype='datetime64[ns]', freq=None)

# %%
ufo = pd.read_csv('DataAnalysis/data/nuforc_reports.csv')

# %%
ufo.head()
# Out:
#                                              summary        city state  \
# 0  My wife was driving southeast on a fairly popu...     Chester    VA
# 1  I think that I may caught a UFO on the NBC Nig...  Rocky Hill    CT
# 2  I woke up late in the afternoon 3:30-4pm. I we...         NaN   NaN
# 3  I was driving towards the intersection of fall...      Ottawa    ON
# 4  In Peoria Arizona, I saw a cigar shaped craft ...      Peoria    NY
#
#              date_time     shape     duration  \
# 0  2019-12-12T18:43:00     light    5 seconds
# 1  2019-03-22T18:30:00    circle  3-5 seconds
# 2                  NaN       NaN          NaN
# 3  2019-04-17T02:00:00  teardrop   10 seconds
# 4  2009-03-15T18:00:00     cigar    2 minutes
#
#                                                stats  \
# 0  Occurred : 12/12/2019 18:43  (Entered as : 12/...
# 1  Occurred : 3/22/2019 18:30  (Entered as : 03/2...
# 2  Occurred : 4/1/2019 15:45  (Entered as : April...
# ...

# %%
pd.to_datetime(ufo.date_time).value_counts().head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
pd.to_datetime(ufo.date_time)
# Out:
# 0       2019-12-12 18:43:00
# 1       2019-03-22 18:30:00
# 2                       NaT
# 3       2019-04-17 02:00:00
# 4       2009-03-15 18:00:00
#                 ...
# 88120   2019-10-02 20:00:00
# 88121   2019-10-02 20:00:00
# 88122   2019-10-02 20:03:00
# 88123   2019-10-02 22:00:00
# 88124   2019-10-02 22:00:00
# Name: date_time, Length: 88125, dtype: datetime64[ns]

# %%
ufo['date'] = pd.to_datetime(ufo.date_time)

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  object
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
#  12  date            86938 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(10)
# memory usage: 8.7+ MB

# %%
ufo
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state            date_time      shape     duration  \
# ...

# %%
ufo.date_time = pd.to_datetime(ufo.date_time)

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
#  12  date            86938 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), object(9)
# memory usage: 8.7+ MB

# %%
ufo = pd.read_csv('DataAnalysis/data/nuforc_reports.csv', parse_dates=['date_time'])

# %%
ufo.date_time.dt.year.value_counts()
# Out:
# 2014.0    8704
# 2012.0    8124
# 2013.0    7823
# 2015.0    6915
# 2019.0    5767
# 2016.0    5664
# 2011.0    5630
# 2008.0    5307
# 2017.0    5057
# 2009.0    4996
# 2010.0    4786
# 2007.0    4736
# 2006.0    3720
# 2018.0    3273
# 2005.0     566
# 2004.0     340
# 1997.0     300
# 2001.0     263
# 2000.0     243
# 2003.0     238
# 1998.0     229
# 2002.0     220
# 1999.0     220
# 1995.0     219
# 1996.0     200
# 1994.0     197
# 1978.0     195
# 1975.0     180
# 1977.0     169
# 1976.0     164
# 1974.0     148
# 1979.0     148
# 1993.0     148
# 1988.0     147
# 1973.0     138
# 1985.0     133
# 1990.0     132
# 1989.0     131
# 1980.0     131
# 1992.0     130
# 1987.0     124
# 1991.0     119
# 1986.0     111
# 1983.0     109
# 1981.0     106
# 1970.0     100
# 1982.0      97
# 1969.0      97
# 1972.0      92
# 1984.0      84
# 1971.0      68
# Name: date_time, dtype: int64

# %%
ufo.date_time.dt.year.value_counts().head(15).plot(kind= 'bar')
# Out:
# <AxesSubplot:>

# %%
ufo.date_time.dt.month.value_counts()
# Out:
# 7.0     10682
# 8.0      8997
# 9.0      8498
# 10.0     8371
# 6.0      8357
# 11.0     7596
# 12.0     6525
# 5.0      6063
# 1.0      5979
# 4.0      5817
# 3.0      5494
# 2.0      4559
# Name: date_time, dtype: int64

# %%
ufo.date_time.dt.month.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
ufo.date_time.dt.hour.value_counts()
# Out:
# 21.0    12851
# 22.0    11660
# 20.0     9565
# 23.0     8194
# 19.0     6460
# 0.0      5577
# 18.0     4462
# 1.0      3285
# 17.0     2660
# 2.0      2216
# 3.0      2088
# 5.0      1874
# 4.0      1641
# 16.0     1612
# 6.0      1588
# 12.0     1408
# 15.0     1380
# 10.0     1334
# 13.0     1308
# 11.0     1301
# 14.0     1280
# 9.0      1126
# 7.0      1067
# 8.0      1001
# Name: date_time, dtype: int64

# %%
ufo.date_time.dt.hour.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
ufo.date_time.dt.minute.value_counts()
# Out:
# 0.0     34565
# 30.0    15402
# 45.0     5480
# 15.0     4874
# 20.0     2744
# 50.0     2457
# 40.0     2323
# 10.0     2058
# 35.0     1586
# 5.0      1471
# 25.0     1408
# 55.0     1094
# 38.0      350
# 23.0      336
# 18.0      310
# 3.0       307
# 1.0       307
# 12.0      306
# 58.0      298
# 22.0      296
# 47.0      289
# 32.0      288
# 43.0      285
# 2.0       284
# 17.0      282
# 34.0      277
# 8.0       275
# 37.0      266
# 28.0      266
# 48.0      265
# 7.0       261
# 24.0      259
# 4.0       250
# 13.0      248
# 14.0      247
# 33.0      241
# 11.0      237
# 42.0      231
# 52.0      228
# 27.0      226
# 16.0      224
# 57.0      214
# 56.0      213
# 53.0      211
# 36.0      207
# 59.0      205
# 26.0      200
# 44.0      198
# 9.0       198
# 19.0      194
# 54.0      193
# 46.0      182
# 6.0       181
# 39.0      180
# 41.0      172
# 49.0      166
# 21.0      161
# 51.0      156
# 29.0      155
# 31.0      151
# Name: date_time, dtype: int64

# %%
ufo.date_time.dt.minute.value_counts().head(20).plot(kind= 'bar')
# Out:
# <AxesSubplot:>

# %%
ufo.date_time.dt.dayofweek.value_counts()
# Out:
# 5.0    16305
# 4.0    12864
# 6.0    12652
# 3.0    11729
# 2.0    11646
# 1.0    10987
# 0.0    10755
# Name: date_time, dtype: int64

# %%
ufo.date_time.dt.dayofweek.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
ufo.date_time.dt.weekday.value_counts()
# Out:
# 5.0    16305
# 4.0    12864
# 6.0    12652
# 3.0    11729
# 2.0    11646
# 1.0    10987
# 0.0    10755
# Name: date_time, dtype: int64

# %%
ufo[ufo.date_time < '1980']
# Out:
#                                                  summary  \
# 8      Ufos report in Irving Texas at 2200 hrs. On or...
# 15        Strange bright light hovered over mobile home.
# 31     Bright green round object quickly travelling e...
# 54     It was a full moon when my brother and I obser...
# 55              UFO over Orangevale, CA in May/June 1969
# ...                                                  ...
# 87166  VERY LARGE OBJECT- WHITE LIGHT ILLUMINATING MY...
# 87167  7 "PEARLESCENT" HIGH ALTITUDE CRAFT IN V FORMA...
# 87168  The even occurred North of Mt Calvary Rd on Ol...
# 87169  Triangle ship passed over silent with 7 green ...
# 87170  While trick or treating with Mom, my Grandma p...
#
#                         city state           date_time     shape  \
# 8                     Dallas    TX 1973-07-14 22:00:00      oval
# 15                Gray Court    SC 1975-07-17 00:00:00     light
# 31     N. Cascades Nat. Park    WA 1979-07-15 23:00:00     light
# ...

# %%
ufo[ufo.date_time > '2019-12-23']
# Out:
#                                                  summary        city state  \
# 85714  7-8 elongated objects flying in straight line ...  Wilmington    NC
#
#                 date_time  shape    duration  \
# 85714 2019-12-29 20:40:00  cigar  10 seconds
#
#                                                    stats  \
# 85714  Occurred : 11/29/2019 20:40  (Entered as : 12/...
#
#                                              report_link  \
# 85714  http://www.nuforc.org/webreports/151/S151158.html
#
#                                                     text               posted  \
# 85714  7-8 elongated objects flying in straight line ...  2019-12-01T00:00:00
#
#        city_latitude  city_longitude
# 85714      34.238375      -77.878468

# %%
ufo[ufo.date_time.dt.hour == 3.0]
# Out:
#                                                  summary  \
# 147                               Round disk with lights
# 177    I stared staring at sky and see nothing but bu...
# 189    The appearance of a tiny saucer, the size of a...
# 207                             Orange pie shaped object
# 294      Dim star that moved sharply,  and intentionally
# ...                                                  ...
# 88030  Over 290 to the east, I heard a single, deep “...
# 88031  small triangular shape with glowing tips obser...
# 88057  Several large green orbs rotating in coordinat...
# 88113  ((NUFORC Note:  Witness does not include any d...
# 88114  I was driving to work and I’m the only one on ...
#
#                              city state           date_time     shape  \
# 147                        Snyder    TX 1991-10-15 03:00:00      disk
# 177                        Rialto    CA 1987-05-22 03:00:00    sphere
# ...

# %%
ufo[ufo.date_time.between('1980', '1990')].sort_values('date_time')
# Out:
#                                                  summary              city  \
# 7996   Very bright green light without sound moved ov...      Indianapolis
# 69297  UFO flew in a zig-zag motion from north to sou...           Laramie
# 4805   Super-colossal circle of rotating lights perpe...           Toronto
# 26562  Two glowing disks seen over an Interstate high...        Pittsburgh
# 31449                                   Tracked by a UFO            Murphy
# ...                                                  ...               ...
# 8540   rectangular, black metallic, hover, silent, hu...         Pineville
# 8307   A brightly lit perfectly round sphere floated ...         Glennwood
# 15542          bright lite making fast moves and complex            Cicero
# 37356                           UFO Santiage, Chile 1989  Santiago (Chile)
# 16502  Large dark triangular object with two round li...         Orrington
#
#       state           date_time      shape    duration  \
# ...

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(9)
# memory usage: 8.1+ MB

# %%
ufo.posted = pd.to_datetime(ufo.posted)

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  datetime64[ns]
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
# dtypes: datetime64[ns](2), float64(2), object(8)
# memory usage: 8.1+ MB

# %%
ufo['time_befor_posted'] = ufo.posted - ufo.date_time

# %%
ufo
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state           date_time      shape     duration  \
# ...

# %%
longest_wait = ufo.sort_values('time_befor_posted', ascending=False).head(10)

# %%
longest_wait
# Out:
#                                                  summary          city state  \
# 86762  An incomplete report given on behalf of anothe...       El Paso    TX
# 87145                      Strange globe sighting--1969.  Philadelphia    PA
# 721    It was July 1969 on a clear summer evening in ...    New Castle    PA
# 1576   1969 olive branch Mississippi large round ligh...  Olive Branch    MS
# 1580   Six bright lights in &quot;V&quot; formation s...      Westport    MA
# 84984  Possible abduction in Colorado in 1969.  ((ano...       Boulder    CO
# 83965  Mysterious light in the sky over Southeren Cal...       Ontario    CA
# 722    Object blended with dark, bright light as if d...           NaN    IN
# 723    The dark object was within 15 feet of me, not ...   West Seneca    NY
# 1301   Elsmere Delaware Linden ave Park Large round n...       Elsmere    DE
#
#                 date_time      shape       duration  \
# 86762 1969-06-01 00:00:00      other      3 minutes
# ...

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   summary            88095 non-null  object
#  1   city               87891 non-null  object
#  2   state              82890 non-null  object
#  3   date_time          86938 non-null  datetime64[ns]
#  4   shape              85627 non-null  object
#  5   duration           84954 non-null  object
#  6   stats              88088 non-null  object
#  7   report_link        88125 non-null  object
#  8   text               88070 non-null  object
#  9   posted             86938 non-null  datetime64[ns]
#  10  city_latitude      72013 non-null  float64
#  11  city_longitude     72013 non-null  float64
#  12  time_befor_posted  86938 non-null  timedelta64[ns]
# dtypes: datetime64[ns](2), float64(2), object(8), timedelta64[ns](1)
# memory usage: 8.7+ MB

# %%
ufo.time_befor_posted
# Out:
# 0          9 days 05:17:00
# 1          6 days 05:30:00
# 2                      NaT
# 3          0 days 22:00:00
# 4       3685 days 06:00:00
#                ...
# 88120      1 days 04:00:00
# 88121      1 days 04:00:00
# 88122      1 days 03:57:00
# 88123      1 days 02:00:00
# 88124      1 days 02:00:00
# Name: time_befor_posted, Length: 88125, dtype: timedelta64[ns]

# %%
longest_wait.time_befor_posted.dt.days /365
# Out:
# 86762    50.583562
# 87145    50.282192
# 721      50.175342
# 1576     50.101370
# 1580     49.972603
# 84984    49.586301
# 83965    49.213699
# 722      49.180822
# 723      49.052055
# 1301     48.967123
# Name: time_befor_posted, dtype: float64

# %%
ufo['days_befor_posted'] = ufo.time_befor_posted.dt.days

# %%
ufo.head()
# Out:
#                                              summary        city state  \
# 0  My wife was driving southeast on a fairly popu...     Chester    VA
# 1  I think that I may caught a UFO on the NBC Nig...  Rocky Hill    CT
# 2  I woke up late in the afternoon 3:30-4pm. I we...         NaN   NaN
# 3  I was driving towards the intersection of fall...      Ottawa    ON
# 4  In Peoria Arizona, I saw a cigar shaped craft ...      Peoria    NY
#
#             date_time     shape     duration  \
# 0 2019-12-12 18:43:00     light    5 seconds
# 1 2019-03-22 18:30:00    circle  3-5 seconds
# 2                 NaT       NaN          NaN
# 3 2019-04-17 02:00:00  teardrop   10 seconds
# 4 2009-03-15 18:00:00     cigar    2 minutes
#
#                                                stats  \
# 0  Occurred : 12/12/2019 18:43  (Entered as : 12/...
# 1  Occurred : 3/22/2019 18:30  (Entered as : 03/2...
# 2  Occurred : 4/1/2019 15:45  (Entered as : April...
# ...

# %%
ufo['years_befor_posted'] = ufo.time_befor_posted.dt.days / 365

# %%
ufo.sort_values('years_befor_posted', ascending=False)
# Out:
#                                                  summary  \
# 86762  An incomplete report given on behalf of anothe...
# 87145                      Strange globe sighting--1969.
# 721    It was July 1969 on a clear summer evening in ...
# 1576   1969 olive branch Mississippi large round ligh...
# 1580   Six bright lights in &quot;V&quot; formation s...
# ...                                                  ...
# 87935  Two bright strobing lights were stationary and...
# 87936  Noticed an uneven, but steady line of craft fl...
# 87937  The stars moved in unison, without breaking fo...
# 87938  White dots in formation just appearing out of ...
# 87939  It can slowly through the gorge about eye leve...
#
#                           city state           date_time      shape  \
# 86762                  El Paso    TX 1969-06-01 00:00:00      other
# 87145             Philadelphia    PA 1969-07-04 01:30:00     sphere
# 721                 New Castle    PA 1969-07-01 21:00:00       disk
# ...

# %%
billboard = pd.read_csv('DataAnalysis/data/billboard_charts.csv', parse_dates=['date'])

# %%
billboard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330087 entries, 0 to 330086
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            330087 non-null  datetime64[ns]
#  1   rank            330087 non-null  int64
#  2   song            330087 non-null  object
#  3   artist          330087 non-null  object
#  4   last-week       297775 non-null  float64
#  5   peak-rank       330087 non-null  int64
#  6   weeks-on-board  330087 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(2)
# memory usage: 17.6+ MB

# %%
billboard
# Out:
#              date  rank                                 song  \
# 0      2021-11-06     1                           Easy On Me
# 1      2021-11-06     2                                 Stay
# 2      2021-11-06     3                        Industry Baby
# 3      2021-11-06     4                           Fancy Like
# 4      2021-11-06     5                           Bad Habits
# ...           ...   ...                                  ...
# 330082 1958-08-04    96                        Over And Over
# 330083 1958-08-04    97                     I Believe In You
# 330084 1958-08-04    98                      Little Serenade
# 330085 1958-08-04    99  I'll Get By (As Long As I Have You)
# 330086 1958-08-04   100                                 Judy
#
#                                artist  last-week  peak-rank  weeks-on-board
# 0                               Adele        1.0          1               3
# 1       The Kid LAROI & Justin Bieber        2.0          1              16
# ...

# %%
billboard.artist.value_counts().head(20)
# Out:
# Taylor Swift          1023
# Elton John             889
# Madonna                857
# Drake                  787
# Kenny Chesney          769
# Tim McGraw             731
# Keith Urban            673
# Stevie Wonder          659
# Rod Stewart            657
# Mariah Carey           621
# Michael Jackson        611
# Chicago                607
# Rascal Flatts          604
# Billy Joel             588
# The Rolling Stones     585
# The Beatles            585
# Jason Aldean           572
# Aretha Franklin        569
# Rihanna                566
# P!nk                   564
# Name: artist, dtype: int64

# %%
billboard.artist.value_counts().head(20).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
number_1s = billboard['rank'] == 1
billboard[number_1s]['artist'].value_counts().head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
billboard[number_1s].song.value_counts().head(20)
# Out:
# Old Town Road                                                       19
# Despacito                                                           16
# One Sweet Day                                                       16
# Rockstar                                                            15
# I'll Make Love To You                                               14
# Uptown Funk!                                                        14
# Macarena (Bayside Boys Mix)                                         14
# I Will Always Love You                                              14
# Candle In The Wind 1997/Something About The Way You Look Tonight    14
# I Gotta Feeling                                                     14
# We Belong Together                                                  14
# End Of The Road (From "Boomerang")                                  13
# Jump                                                                13
# ...

# %%
billboard[number_1s].song.value_counts().head(20).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
billboard[billboard.song == 'Old Town Road'].set_index('date')['rank'].plot()
# Out:
# <AxesSubplot:xlabel='date'>
