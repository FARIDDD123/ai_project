# %%
import pandas as pd

# %%
carstock = pd.read_csv('DataAnalysis/data/car_stocks.csv')

# %%
carstock
# Out:
#    Symbol        Date        Open        High         Low       Close  \
# 0    RIVN  2021-11-10  106.750000  119.459999   95.199997  100.730003
# 1    RIVN  2021-11-11  114.625000  125.000000  108.010002  122.989998
# 2    RIVN  2021-11-12  128.645004  135.199997  125.250000  129.949997
# 3    RIVN  2021-11-15  130.800003  152.529999  127.510002  149.360001
# 4    RIVN  2021-11-16  163.800003  179.470001  153.779999  172.009995
# 5    RIVN  2021-11-17  160.880005  163.000000  140.350006  146.070007
# 6    RIVN  2021-11-18  136.809998  138.779999  120.150002  123.379997
# 7    RIVN  2021-11-19  129.979996  139.899994  125.599998  128.600006
# 8    RIVN  2021-11-22  123.879997  124.930000  106.910004  118.110001
# 9    RIVN  2021-11-23  117.830002  124.000000  113.000000  119.849998
# 10   RIVN  2021-11-24  119.379997  120.000000  113.449997  114.849998
# 11   RIVN  2021-11-26  111.000000  114.500000  106.139999  112.129997
# ...

# %%
carstock[carstock['Symbol'] == 'GM']['Close'].mean()
# Out:
# 62.16461546153845

# %%
carstock[carstock['Symbol'] == 'RIVN']['Close'].mean()
# Out:
# 127.52307653846154

# %%
carstock[carstock['Symbol'] == 'LCID']['Close'].mean()
# Out:
# 49.82923061538462

# %%
carstock.groupby('Symbol')['Close'].mean().plot(kind='bar')bbb
# Out:
# <AxesSubplot:xlabel='Symbol'>

# %%
titanic = pd.read_csv('DataAnalysis/data/titanic.csv')
titanic['age'] = titanic['age'].replace(['?'], [None]).astype(float)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 143.3+ KB

# %%
titanic.age.value_counts()
# Out:
# 24.0000    47
# 22.0000    43
# 21.0000    41
# 30.0000    40
# 18.0000    39
#            ..
# 0.3333      1
# 22.5000     1
# 70.5000     1
# 0.6667      1
# 26.5000     1
# Name: age, Length: 98, dtype: int64

# %%
df = titanic[['pclass', 'survived', 'sex', 'age']]

# %%
gbo = df.groupby('sex')

# %%
gbo.ngroups
# Out:
# 2

# %%
gbo.groups
# Out:
# {'female': [0, 2, 4, 6, 8, 11, 12, 13, 17, 18, 21, 23, 24, 27, 28, 32, 33, 35, 36, 41, 42, 43, 44, 48, 50, 55, 57, 59, 61, 63, 65, 66, 67, 69, 72, 73, 76, 78, 79, 82, 83, 85, 88, 90, 92, 95, 97, 98, 99, 102, 103, 104, 105, 107, 108, 111, 112, 113, 116, 117, 121, 122, 124, 127, 129, 130, 131, 134, 137, 139, 141, 144, 146, 149, 153, 155, 159, 160, 161, 163, 167, 168, 169, 176, 178, 180, 181, 182, 186, 187, 188, 190, 192, 193, 195, 198, 199, 204, 207, 208, ...], 'male': [1, 3, 5, 7, 9, 10, 14, 15, 16, 19, 20, 22, 25, 26, 29, 30, 31, 34, 37, 38, 39, 40, 45, 46, 47, 49, 51, 52, 53, 54, 56, 58, 60, 62, 64, 68, 70, 71, 74, 75, 77, 80, 81, 84, 86, 87, 89, 91, 93, 94, 96, 100, 101, 106, 109, 110, 114, 115, 118, 119, 120, 123, 125, 126, 128, 132, 133, 135, 136, 138, 140, 142, 143, 145, 147, 148, 150, 151, 152, 154, 156, 157, 158, 162, 164, 165, 166, 170, 171, 172, 173, 174, 175, 177, 179, 183, 184, 185, 189, 191, ...]}

# %%
df.groupby('age').ngroups
# Out:
# 98

# %%
df.groupby('age').groups
# Out:
# {0.1667: [763], 0.3333: [747], 0.4167: [1240], 0.6667: [427], 0.75: [657, 658, 1111], 0.8333: [359, 548, 611], 0.9167: [1, 590], 1.0: [339, 478, 492, 762, 826, 895, 937, 1048, 1101, 1187], 2.0: [2, 514, 540, 587, 624, 866, 1096, 1103, 1144, 1156, 1209, 1230], 3.0: [479, 515, 549, 641, 734, 1098, 1112], 4.0: [94, 340, 588, 622, 894, 916, 934, 1142, 1189, 1206], 5.0: [591, 639, 643, 659, 794], 6.0: [273, 430, 623, 678, 1025, 1097], 7.0: [434, 1102, 1143, 1256], 8.0: [377, 385, 398, 541, 1099, 1145], 9.0: [627, 640, 679, 733, 807, 820, 825, 1082, 1208, 1257], 10.0: [828, 1141, 1207, 1265], 11.0: [54, 628, 827, 855], 11.5: [1263], 12.0: [341, 582, 1056], 13.0: [249, 501, 601, 642, 653], 14.0: [55, 513, 569, 830, 1057, 1105, 1236, 1279], 14.5: [1171, 1304], 15.0: [193, 350, 792, 1007, 1047, 1300], 16.0: [159, 187, 195, 416, 510, 602, 604, 709, 761, 787, 810, 818, 829, 1093, 1104, 1161, 1232, 1244, 1275], 17.0: [53, 92, 229, 295, 390, 458, 482, 625, 650, 700, 701, 738, 740, 755, 772, 791, 
# ...

# %%
gbo.first()
# Out:
#         pclass  survived      age
# sex
# female       1         1  29.0000
# male         1         1   0.9167

# %%
gbo['age'].first()
# Out:
# sex
# female    29.0000
# male       0.9167
# Name: age, dtype: float64

# %%
df.groupby('age').first()
# Out:
#          pclass  survived     sex
# age
# 0.1667        3         1  female
# 0.3333        3         0    male
# 0.4167        3         1    male
# 0.6667        2         1    male
# 0.7500        3         1  female
# ...         ...       ...     ...
# 70.5000       3         0    male
# 71.0000       1         0    male
# 74.0000       3         0    male
# 76.0000       1         1  female
# 80.0000       1         1    male
#
# [98 rows x 3 columns]

# %%
gbo.get_group('male')
# Out:
#       pclass  survived   sex      age
# 1          1         1  male   0.9167
# 3          1         0  male  30.0000
# 5          1         1  male  48.0000
# 7          1         0  male  39.0000
# 9          1         0  male  71.0000
# ...      ...       ...   ...      ...
# 1302       3         0  male      NaN
# 1303       3         0  male      NaN
# 1306       3         0  male  26.5000
# 1307       3         0  male  27.0000
# 1308       3         0  male  29.0000
#
# [843 rows x 4 columns]

# %%
gbo.get_group('female')
# Out:
#       pclass  survived     sex   age
# 0          1         1  female  29.0
# 2          1         0  female   2.0
# 4          1         0  female  25.0
# 6          1         1  female  63.0
# 8          1         1  female  53.0
# ...      ...       ...     ...   ...
# 1286       3         1  female  38.0
# 1290       3         1  female  47.0
# 1300       3         1  female  15.0
# 1304       3         0  female  14.5
# 1305       3         0  female   NaN
#
# [466 rows x 4 columns]

# %%
for name, group in gbo:
    print(name)
    print('-----------------')
    print(group)
# Out:
# female
# -----------------
#       pclass  survived     sex   age
# 0          1         1  female  29.0
# 2          1         0  female   2.0
# 4          1         0  female  25.0
# 6          1         1  female  63.0
# 8          1         1  female  53.0
# ...      ...       ...     ...   ...
# 1286       3         1  female  38.0
# 1290       3         1  female  47.0
# 1300       3         1  female  15.0
# 1304       3         0  female  14.5
# 1305       3         0  female   NaN
#
# [466 rows x 4 columns]
# male
# -----------------
#       pclass  survived   sex      age
# 1          1         1  male   0.9167
# 3          1         0  male  30.0000
# 5          1         1  male  48.0000
# 7          1         0  male  39.0000
# 9          1         0  male  71.0000
# ...      ...       ...   ...      ...
# 1302       3         0  male      NaN
# 1303       3         0  male      NaN
# 1306       3         0  male  26.5000
# 1307       3         0  male  27.0000
# ...

# %%
gbo['age'].mean()
# Out:
# sex
# female    28.687071
# male      30.585233
# Name: age, dtype: float64

# %%
gbo['age'].max()
# Out:
# sex
# female    76.0
# male      80.0
# Name: age, dtype: float64

# %%
gbo['age'].std()
# Out:
# sex
# female    14.576995
# male      14.280571
# Name: age, dtype: float64

# %%
gbo['age'].sum()
# Out:
# sex
# female    11130.5834
# male      20125.0833
# Name: age, dtype: float64

# %%
gbo['age'].mean().plot(kind='pie', title = 'Average Age By Sex', colors = ['#192a56', '#55efc4'], shadow = True, explode= (0, 0.04))
# Out:
# <AxesSubplot:title={'center':'Average Age By Sex'}, ylabel='age'>

# %%
titanic.groupby('pclass')['age'].mean()
# Out:
# pclass
# 1    39.159918
# 2    29.506705
# 3    24.816367
# Name: age, dtype: float64

# %%
titanic.groupby('pclass')['age'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='pclass'>

# %%
titanic.groupby('survived')['age'].mean()
# Out:
# survived
# 0    30.545369
# 1    28.918228
# Name: age, dtype: float64

# %%
titanic.groupby('survived')['age'].max()
# Out:
# survived
# 0    74.0
# 1    80.0
# Name: age, dtype: float64

# %%
titanic.groupby('sex').mean()
# Out:
#           pclass  survived        age     sibsp     parch
# sex
# female  2.154506  0.727468  28.687071  0.652361  0.633047
# male    2.372479  0.190985  30.585233  0.413998  0.247924

# %%
gbo['age'].mean()
# Out:
# sex
# female    28.687071
# male      30.585233
# Name: age, dtype: float64

# %%
carstock.groupby('Symbol').mean()
# Out:
#               Open        High         Low       Close   Adj Close  \
# Symbol
# GM       61.937693   63.129231   61.051539   62.164615   62.164615
# LCID     48.761538   51.811538   46.442539   49.829231   49.829231
# RIVN    127.710000  135.309230  119.150000  127.523077  127.523077
#
#               Volume
# Symbol
# GM      2.025259e+07
# LCID    1.081098e+08
# RIVN    5.252395e+07

# %%
carstock.groupby('Symbol').max()
# Out:
#               Date        Open        High         Low       Close  \
# Symbol
# GM      2021-11-29   64.330002   65.180000   62.630001   64.610001
# LCID    2021-11-29   56.200001   57.750000   50.709999   55.520000
# RIVN    2021-11-29  163.800003  179.470001  153.779999  172.009995
#
#          Adj Close     Volume
# Symbol
# GM       64.610001   31142800
# LCID     55.520000  248654600
# RIVN    172.009995  103679500

# %%
titanic.groupby('sex')['age'].agg(['min', 'max', 'mean', 'std'])
# Out:
#            min   max       mean        std
# sex
# female  0.1667  76.0  28.687071  14.576995
# male    0.3333  80.0  30.585233  14.280571

# %%
carstock.groupby('Symbol')['Close'].agg(['min', 'max', 'mean'])
# Out:
#                min         max        mean
# Symbol
# GM       59.270000   64.610001   62.164615
# LCID     40.750000   55.520000   49.829231
# RIVN    100.730003  172.009995  127.523077

# %%
titanic.groupby('sex').agg({'age' : ['max', 'min'], 'pclass' : ['mean']})
# Out:
#          age            pclass
#          max     min      mean
# sex
# female  76.0  0.1667  2.154506
# male    80.0  0.3333  2.372479

# %%
carstock.groupby('Symbol').agg({'Open' : ['max', 'min'], 'Close' : ['max', 'min'], 'Adj Close' : 'mean'})
# Out:
#               Open                   Close               Adj Close
#                max         min         max         min        mean
# Symbol
# GM       64.330002   57.849998   64.610001   59.270000   62.164615
# LCID     56.200001   42.299999   55.520000   40.750000   49.829231
# RIVN    163.800003  106.750000  172.009995  100.730003  127.523077

# %%
btc= pd.read_csv('DataAnalysis/data/coin_Bitcoin.csv')

# %%
btc.groupby('Date')['Marketcap'].min()
# Out:
# Date
# 2013-04-29 23:59:59    1.603769e+09
# 2013-04-30 23:59:59    1.542813e+09
# 2013-05-01 23:59:59    1.298955e+09
# 2013-05-02 23:59:59    1.168517e+09
# 2013-05-03 23:59:59    1.085995e+09
#                            ...
# 2021-07-02 23:59:59    6.354508e+11
# 2021-07-03 23:59:59    6.499397e+11
# 2021-07-04 23:59:59    6.615748e+11
# 2021-07-05 23:59:59    6.326962e+11
# 2021-07-06 23:59:59    6.418992e+11
# Name: Marketcap, Length: 2991, dtype: float64

# %%
btc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2991 entries, 0 to 2990
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SNo        2991 non-null   int64
#  1   Name       2991 non-null   object
#  2   Symbol     2991 non-null   object
#  3   Date       2991 non-null   object
#  4   High       2991 non-null   float64
#  5   Low        2991 non-null   float64
#  6   Open       2991 non-null   float64
#  7   Close      2991 non-null   float64
#  8   Volume     2991 non-null   float64
#  9   Marketcap  2991 non-null   float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 233.8+ KB

# %%
btc
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %%
btc.groupby('Date').agg({'Close' : ['max', 'min'], 'Marketcap' : 'mean'})
# Out:
#                             Close                   Marketcap
#                               max           min          mean
# Date
# 2013-04-29 23:59:59    144.539993    144.539993  1.603769e+09
# 2013-04-30 23:59:59    139.000000    139.000000  1.542813e+09
# 2013-05-01 23:59:59    116.989998    116.989998  1.298955e+09
# 2013-05-02 23:59:59    105.209999    105.209999  1.168517e+09
# 2013-05-03 23:59:59     97.750000     97.750000  1.085995e+09
# ...                           ...           ...           ...
# 2021-07-02 23:59:59  33897.048590  33897.048590  6.354508e+11
# 2021-07-03 23:59:59  34668.548402  34668.548402  6.499397e+11
# 2021-07-04 23:59:59  35287.779766  35287.779766  6.615748e+11
# 2021-07-05 23:59:59  33746.002456  33746.002456  6.326962e+11
# 2021-07-06 23:59:59  34235.193451  34235.193451  6.418992e+11
#
# [2991 rows x 3 columns]

# %%
carstock.groupby('Symbol').agg({'Close' : 'mean', 'Open' : 'mean'}).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Symbol'>

# %%
btc.groupby('Symbol').agg({'Marketcap' : ['max','min'], 'Date' : ['min', 'min']})
# Out:
#            Marketcap                               Date
#                  max           min                  min                  min
# Symbol
# BTC     1.186364e+12  7.784112e+08  2013-04-29 23:59:59  2013-04-29 23:59:59

# %%
titanic.groupby('sex').agg({ 'survived' : ['max', 'min'], 'pclass' : ['max', 'min']}).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
def range(s):
    return s.max() - s.min()
titanic.groupby('pclass')['age'].agg(['max', 'min', range])
# Out:
#          max     min    range
# pclass
# 1       80.0  0.9167  79.0833
# 2       70.0  0.6667  69.3333
# 3       74.0  0.1667  73.8333

# %%
def means(s):
    return s.mean()
carstock.groupby('Symbol')['Open'].agg(['min', 'max', means])
# Out:
#                min         max       means
# Symbol
# GM       57.849998   64.330002   61.937693
# LCID     42.299999   56.200001   48.761538
# RIVN    106.750000  163.800003  127.710000

# %%
carstock
# Out:
#    Symbol        Date        Open        High         Low       Close  \
# 0    RIVN  2021-11-10  106.750000  119.459999   95.199997  100.730003
# 1    RIVN  2021-11-11  114.625000  125.000000  108.010002  122.989998
# 2    RIVN  2021-11-12  128.645004  135.199997  125.250000  129.949997
# 3    RIVN  2021-11-15  130.800003  152.529999  127.510002  149.360001
# 4    RIVN  2021-11-16  163.800003  179.470001  153.779999  172.009995
# 5    RIVN  2021-11-17  160.880005  163.000000  140.350006  146.070007
# 6    RIVN  2021-11-18  136.809998  138.779999  120.150002  123.379997
# 7    RIVN  2021-11-19  129.979996  139.899994  125.599998  128.600006
# 8    RIVN  2021-11-22  123.879997  124.930000  106.910004  118.110001
# 9    RIVN  2021-11-23  117.830002  124.000000  113.000000  119.849998
# 10   RIVN  2021-11-24  119.379997  120.000000  113.449997  114.849998
# 11   RIVN  2021-11-26  111.000000  114.500000  106.139999  112.129997
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 143.3+ KB

# %%
titanic.age.count()
# Out:
# 1046

# %%
def num_null(s):
    return s.size - s.count()
titanic.groupby('pclass')['age'].agg(num_null)
# Out:
# pclass
# 1     39
# 2     16
# 3    208
# Name: age, dtype: int64

# %%
titanic.age.size - titanic.age.count()
# Out:
# 263

# %%
btc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2991 entries, 0 to 2990
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SNo        2991 non-null   int64
#  1   Name       2991 non-null   object
#  2   Symbol     2991 non-null   object
#  3   Date       2991 non-null   object
#  4   High       2991 non-null   float64
#  5   Low        2991 non-null   float64
#  6   Open       2991 non-null   float64
#  7   Close      2991 non-null   float64
#  8   Volume     2991 non-null   float64
#  9   Marketcap  2991 non-null   float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 233.8+ KB

# %%
carstock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Symbol     39 non-null     object
#  1   Date       39 non-null     object
#  2   Open       39 non-null     float64
#  3   High       39 non-null     float64
#  4   Low        39 non-null     float64
#  5   Close      39 non-null     float64
#  6   Adj Close  39 non-null     float64
#  7   Volume     39 non-null     int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 2.6+ KB

# %%
def average(s):
    return s.max() - s.min()

carstock.groupby('Symbol').agg(
    open_min = ('Open', 'min'),
    open_max = ('Open', 'max')
)
# Out:
#           open_min    open_max
# Symbol
# GM       57.849998   64.330002
# LCID     42.299999   56.200001
# RIVN    106.750000  163.800003
